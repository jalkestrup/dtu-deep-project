# %% [markdown]
# # Training results from LLM2Vec runs

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### LLM2Vec LLama DK MNTP
# MNTP Training on Danish Wikipedia, using LLM2Vec train script

# %%
llama_en_mntp_en = {
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 0.13491635186184567,
  "eval_steps": 100,
  "global_step": 1000,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.013491635186184566,
      "eval_accuracy": 0.6718419898752341,
      "eval_loss": 1.5084404945373535,
      "eval_runtime": 32.2825,
      "eval_samples_per_second": 15.457,
      "eval_steps_per_second": 0.496,
      "step": 100
    },
    {
      "epoch": 0.026983270372369132,
      "eval_accuracy": 0.7050768070495773,
      "eval_loss": 1.3584702014923096,
      "eval_runtime": 32.2845,
      "eval_samples_per_second": 15.456,
      "eval_steps_per_second": 0.496,
      "step": 200
    },
    {
      "epoch": 0.040474905558553695,
      "eval_accuracy": 0.719758346836304,
      "eval_loss": 1.2450056076049805,
      "eval_runtime": 32.2874,
      "eval_samples_per_second": 15.455,
      "eval_steps_per_second": 0.496,
      "step": 300
    },
    {
      "epoch": 0.053966540744738264,
      "eval_accuracy": 0.7262788365095286,
      "eval_loss": 1.228310465812683,
      "eval_runtime": 32.1888,
      "eval_samples_per_second": 15.502,
      "eval_steps_per_second": 0.497,
      "step": 400
    },
    {
      "epoch": 0.06745817593092283,
      "grad_norm": 2.131291389465332,
      "learning_rate": 4.887569706781795e-05,
      "loss": 1.5204,
      "step": 500
    },
    {
      "epoch": 0.06745817593092283,
      "eval_accuracy": 0.7320318725099602,
      "eval_loss": 1.1885204315185547,
      "eval_runtime": 32.3079,
      "eval_samples_per_second": 15.445,
      "eval_steps_per_second": 0.495,
      "step": 500
    },
    {
      "epoch": 0.08094981111710739,
      "eval_accuracy": 0.7340408490188226,
      "eval_loss": 1.1743415594100952,
      "eval_runtime": 32.2824,
      "eval_samples_per_second": 15.457,
      "eval_steps_per_second": 0.496,
      "step": 600
    },
    {
      "epoch": 0.09444144630329196,
      "eval_accuracy": 0.7378092577813248,
      "eval_loss": 1.1658198833465576,
      "eval_runtime": 32.1431,
      "eval_samples_per_second": 15.524,
      "eval_steps_per_second": 0.498,
      "step": 700
    },
    {
      "epoch": 0.10793308148947653,
      "eval_accuracy": 0.7428798569015205,
      "eval_loss": 1.1376597881317139,
      "eval_runtime": 32.2439,
      "eval_samples_per_second": 15.476,
      "eval_steps_per_second": 0.496,
      "step": 800
    },
    {
      "epoch": 0.12142471667566108,
      "eval_accuracy": 0.744721460097817,
      "eval_loss": 1.1187114715576172,
      "eval_runtime": 32.2479,
      "eval_samples_per_second": 15.474,
      "eval_steps_per_second": 0.496,
      "step": 900
    },
    {
      "epoch": 0.13491635186184567,
      "grad_norm": 1.9977185726165771,
      "learning_rate": 4.775139413563591e-05,
      "loss": 1.1656,
      "step": 1000
    },
    {
      "epoch": 0.13491635186184567,
      "eval_accuracy": 0.7448173153296267,
      "eval_loss": 1.1213704347610474,
      "eval_runtime": 32.2101,
      "eval_samples_per_second": 15.492,
      "eval_steps_per_second": 0.497,
      "step": 1000
    }
  ],
  "logging_steps": 500,
  "max_steps": 22236,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 500,
  "total_flos": 7.41887283560448e+17,
  "train_batch_size": 32,
  "trial_name": None,
  "trial_params": None
}

# %%
llama_en_mntp_da = {
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 0.23573785950023574,
  "eval_steps": 100,
  "global_step": 1000,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.023573785950023574,
      "eval_accuracy": 0.5871326233424168,
      "eval_loss": 2.1859824657440186,
      "eval_runtime": 492.4524,
      "eval_samples_per_second": 15.508,
      "eval_steps_per_second": 0.485,
      "step": 100
    },
    {
      "epoch": 0.04714757190004715,
      "eval_accuracy": 0.6663690059373679,
      "eval_loss": 1.6759679317474365,
      "eval_runtime": 492.6872,
      "eval_samples_per_second": 15.501,
      "eval_steps_per_second": 0.485,
      "step": 200
    },
    {
      "epoch": 0.07072135785007072,
      "eval_accuracy": 0.7010020513426153,
      "eval_loss": 1.4581284523010254,
      "eval_runtime": 493.1003,
      "eval_samples_per_second": 15.488,
      "eval_steps_per_second": 0.485,
      "step": 300
    },
    {
      "epoch": 0.0942951438000943,
      "eval_accuracy": 0.7218450681635926,
      "eval_loss": 1.3426454067230225,
      "eval_runtime": 492.9177,
      "eval_samples_per_second": 15.493,
      "eval_steps_per_second": 0.485,
      "step": 400
    },
    {
      "epoch": 0.11786892975011787,
      "grad_norm": 2.773155927658081,
      "learning_rate": 4.803551783749804e-05,
      "loss": 1.9408,
      "step": 500
    },
    {
      "epoch": 0.11786892975011787,
      "eval_accuracy": 0.7346415210569883,
      "eval_loss": 1.2690852880477905,
      "eval_runtime": 492.7914,
      "eval_samples_per_second": 15.497,
      "eval_steps_per_second": 0.485,
      "step": 500
    },
    {
      "epoch": 0.14144271570014144,
      "eval_accuracy": 0.7458355460802951,
      "eval_loss": 1.2015537023544312,
      "eval_runtime": 492.7134,
      "eval_samples_per_second": 15.5,
      "eval_steps_per_second": 0.485,
      "step": 600
    },
    {
      "epoch": 0.16501650165016502,
      "eval_accuracy": 0.7547212380078248,
      "eval_loss": 1.1552379131317139,
      "eval_runtime": 493.1426,
      "eval_samples_per_second": 15.486,
      "eval_steps_per_second": 0.485,
      "step": 700
    },
    {
      "epoch": 0.1885902876001886,
      "eval_accuracy": 0.7603330634902278,
      "eval_loss": 1.1236579418182373,
      "eval_runtime": 493.0154,
      "eval_samples_per_second": 15.49,
      "eval_steps_per_second": 0.485,
      "step": 800
    },
    {
      "epoch": 0.21216407355021216,
      "eval_accuracy": 0.7679632061723984,
      "eval_loss": 1.0834029912948608,
      "eval_runtime": 492.9013,
      "eval_samples_per_second": 15.494,
      "eval_steps_per_second": 0.485,
      "step": 900
    },
    {
      "epoch": 0.23573785950023574,
      "grad_norm": 2.5210537910461426,
      "learning_rate": 4.607103567499607e-05,
      "loss": 1.1443,
      "step": 1000
    },
    {
      "epoch": 0.23573785950023574,
      "eval_accuracy": 0.7724336812775887,
      "eval_loss": 1.057970404624939,
      "eval_runtime": 492.9349,
      "eval_samples_per_second": 15.493,
      "eval_steps_per_second": 0.485,
      "step": 1000
    },
    {
      "epoch": 0.23573785950023574,
      "step": 1000,
      "total_flos": 7.41887283560448e+17,
      "train_loss": 1.5425711669921875,
      "train_runtime": 11800.4057,
      "train_samples_per_second": 34.504,
      "train_steps_per_second": 1.078
    }
  ],
  "logging_steps": 500,
  "max_steps": 12726,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 200,
  "total_flos": 7.41887283560448e+17,
  "train_batch_size": 32,
  "trial_name": None,
  "trial_params": None
}

llama_swe_mntp_da = {
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 0.23573785950023574,
  "eval_steps": 100,
  "global_step": 1000,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.023573785950023574,
      "eval_accuracy": 0.6317716870477788,
      "eval_loss": 1.8646224737167358,
      "eval_runtime": 492.4929,
      "eval_samples_per_second": 15.507,
      "eval_steps_per_second": 0.485,
      "step": 100
    },
    {
      "epoch": 0.04714757190004715,
      "eval_accuracy": 0.7021049967171662,
      "eval_loss": 1.4454373121261597,
      "eval_runtime": 492.5577,
      "eval_samples_per_second": 15.505,
      "eval_steps_per_second": 0.485,
      "step": 200
    },
    {
      "epoch": 0.07072135785007072,
      "eval_accuracy": 0.7335578085807225,
      "eval_loss": 1.2683207988739014,
      "eval_runtime": 492.7056,
      "eval_samples_per_second": 15.5,
      "eval_steps_per_second": 0.485,
      "step": 300
    },
    {
      "epoch": 0.0942951438000943,
      "eval_accuracy": 0.7496352846832398,
      "eval_loss": 1.1724069118499756,
      "eval_runtime": 492.418,
      "eval_samples_per_second": 15.509,
      "eval_steps_per_second": 0.485,
      "step": 400
    },
    {
      "epoch": 0.11786892975011787,
      "grad_norm": 3.823148250579834,
      "learning_rate": 4.803551783749804e-05,
      "loss": 1.7013,
      "step": 500
    },
    {
      "epoch": 0.11786892975011787,
      "eval_accuracy": 0.7622726018519113,
      "eval_loss": 1.1071853637695312,
      "eval_runtime": 492.5647,
      "eval_samples_per_second": 15.505,
      "eval_steps_per_second": 0.485,
      "step": 500
    },
    {
      "epoch": 0.14144271570014144,
      "eval_accuracy": 0.7731863812800325,
      "eval_loss": 1.0427114963531494,
      "eval_runtime": 492.2995,
      "eval_samples_per_second": 15.513,
      "eval_steps_per_second": 0.485,
      "step": 600
    },
    {
      "epoch": 0.16501650165016502,
      "eval_accuracy": 0.7809848069202094,
      "eval_loss": 1.003616452217102,
      "eval_runtime": 492.5831,
      "eval_samples_per_second": 15.504,
      "eval_steps_per_second": 0.485,
      "step": 700
    },
    {
      "epoch": 0.1885902876001886,
      "eval_accuracy": 0.7868278015496704,
      "eval_loss": 0.9764024615287781,
      "eval_runtime": 492.4908,
      "eval_samples_per_second": 15.507,
      "eval_steps_per_second": 0.485,
      "step": 800
    },
    {
      "epoch": 0.21216407355021216,
      "eval_accuracy": 0.7921159020990164,
      "eval_loss": 0.94410640001297,
      "eval_runtime": 492.6567,
      "eval_samples_per_second": 15.502,
      "eval_steps_per_second": 0.485,
      "step": 900
    },
    {
      "epoch": 0.23573785950023574,
      "grad_norm": 2.0617034435272217,
      "learning_rate": 4.607103567499607e-05,
      "loss": 0.9942,
      "step": 1000
    },
    {
      "epoch": 0.23573785950023574,
      "eval_accuracy": 0.7963057274181528,
      "eval_loss": 0.9231188297271729,
      "eval_runtime": 492.777,
      "eval_samples_per_second": 15.498,
      "eval_steps_per_second": 0.485,
      "step": 1000
    },
    {
      "epoch": 0.23573785950023574,
      "step": 1000,
      "total_flos": 7.41887283560448e+17,
      "train_loss": 1.3477576904296875,
      "train_runtime": 11785.9066,
      "train_samples_per_second": 34.547,
      "train_steps_per_second": 1.08
    }
  ],
  "logging_steps": 500,
  "max_steps": 12726,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 200,
  "total_flos": 7.41887283560448e+17,
  "train_batch_size": 32,
  "trial_name": None,
  "trial_params": None
}

llama_swe_mntp_da_long_train = {
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 0.7513148009015778,
  "eval_steps": 250,
  "global_step": 3000,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.06260956674179814,
      "eval_accuracy": 0.7010753947608555,
      "eval_loss": 1.449791431427002,
      "eval_runtime": 463.6786,
      "eval_samples_per_second": 15.511,
      "eval_steps_per_second": 0.485,
      "step": 250
    },
    {
      "epoch": 0.12521913348359628,
      "grad_norm": 2.6045312881469727,
      "learning_rate": 4.791301444194006e-05,
      "loss": 1.7757,
      "step": 500
    },
    {
      "epoch": 0.12521913348359628,
      "eval_accuracy": 0.7524309813860954,
      "eval_loss": 1.1587307453155518,
      "eval_runtime": 463.9146,
      "eval_samples_per_second": 15.503,
      "eval_steps_per_second": 0.485,
      "step": 500
    },
    {
      "epoch": 0.18782870022539444,
      "eval_accuracy": 0.7710523551710639,
      "eval_loss": 1.0503803491592407,
      "eval_runtime": 463.9935,
      "eval_samples_per_second": 15.5,
      "eval_steps_per_second": 0.485,
      "step": 750
    },
    {
      "epoch": 0.25043826696719257,
      "grad_norm": 2.281813621520996,
      "learning_rate": 4.582602888388012e-05,
      "loss": 1.0486,
      "step": 1000
    },
    {
      "epoch": 0.25043826696719257,
      "eval_accuracy": 0.7832352949182438,
      "eval_loss": 0.9868106842041016,
      "eval_runtime": 463.8784,
      "eval_samples_per_second": 15.504,
      "eval_steps_per_second": 0.485,
      "step": 1000
    },
    {
      "epoch": 0.31304783370899075,
      "eval_accuracy": 0.7911818163252803,
      "eval_loss": 0.9450885653495789,
      "eval_runtime": 464.0071,
      "eval_samples_per_second": 15.5,
      "eval_steps_per_second": 0.485,
      "step": 1250
    },
    {
      "epoch": 0.3756574004507889,
      "grad_norm": 2.1908669471740723,
      "learning_rate": 4.373904332582019e-05,
      "loss": 0.9401,
      "step": 1500
    },
    {
      "epoch": 0.3756574004507889,
      "eval_accuracy": 0.796934662200756,
      "eval_loss": 0.9140136241912842,
      "eval_runtime": 463.8488,
      "eval_samples_per_second": 15.505,
      "eval_steps_per_second": 0.485,
      "step": 1500
    },
    {
      "epoch": 0.438266967192587,
      "eval_accuracy": 0.8019559968789022,
      "eval_loss": 0.8904263377189636,
      "eval_runtime": 463.36,
      "eval_samples_per_second": 15.521,
      "eval_steps_per_second": 0.486,
      "step": 1750
    },
    {
      "epoch": 0.5008765339343851,
      "grad_norm": 1.9689815044403076,
      "learning_rate": 4.165205776776025e-05,
      "loss": 0.8842,
      "step": 2000
    },
    {
      "epoch": 0.5008765339343851,
      "eval_accuracy": 0.8070731052820129,
      "eval_loss": 0.8661556839942932,
      "eval_runtime": 463.9029,
      "eval_samples_per_second": 15.503,
      "eval_steps_per_second": 0.485,
      "step": 2000
    },
    {
      "epoch": 0.5634861006761833,
      "eval_accuracy": 0.8086464997656702,
      "eval_loss": 0.8534561395645142,
      "eval_runtime": 463.6796,
      "eval_samples_per_second": 15.511,
      "eval_steps_per_second": 0.485,
      "step": 2250
    },
    {
      "epoch": 0.6260956674179815,
      "grad_norm": 2.0928614139556885,
      "learning_rate": 3.956507220970031e-05,
      "loss": 0.8473,
      "step": 2500
    },
    {
      "epoch": 0.6260956674179815,
      "eval_accuracy": 0.8134334040354598,
      "eval_loss": 0.8301207423210144,
      "eval_runtime": 463.7854,
      "eval_samples_per_second": 15.507,
      "eval_steps_per_second": 0.485,
      "step": 2500
    },
    {
      "epoch": 0.6887052341597796,
      "eval_accuracy": 0.8158200329839578,
      "eval_loss": 0.8179028630256653,
      "eval_runtime": 463.6528,
      "eval_samples_per_second": 15.512,
      "eval_steps_per_second": 0.485,
      "step": 2750
    },
    {
      "epoch": 0.7513148009015778,
      "grad_norm": 1.957603096961975,
      "learning_rate": 3.747808665164037e-05,
      "loss": 0.8188,
      "step": 3000
    },
    {
      "epoch": 0.7513148009015778,
      "eval_accuracy": 0.8176456557148017,
      "eval_loss": 0.8092158436775208,
      "eval_runtime": 463.678,
      "eval_samples_per_second": 15.511,
      "eval_steps_per_second": 0.485,
      "step": 3000
    },
    {
      "epoch": 0.7513148009015778,
      "step": 3000,
      "total_flos": 2.225661850681344e+18,
      "train_loss": 1.0524715576171875,
      "train_runtime": 26129.3989,
      "train_samples_per_second": 14.669,
      "train_steps_per_second": 0.458
    }
  ],
  "logging_steps": 500,
  "max_steps": 11979,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 500,
  "total_flos": 2.225661850681344e+18,
  "train_batch_size": 32,
  "trial_name": None,
  "trial_params": None
}

# %%
llama_swe_mntp_scandi = { #Trained on mix of scandinavian languages
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 0.19063959584405682,
  "eval_steps": 200,
  "global_step": 2000,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.019063959584405682,
      "eval_accuracy": 0.6766402862189922,
      "eval_loss": 1.5877882242202759,
      "eval_runtime": 1128.2057,
      "eval_samples_per_second": 15.517,
      "eval_steps_per_second": 0.486,
      "step": 200
    },
    {
      "epoch": 0.038127919168811364,
      "eval_accuracy": 0.7249642161946639,
      "eval_loss": 1.3184435367584229,
      "eval_runtime": 1127.8694,
      "eval_samples_per_second": 15.521,
      "eval_steps_per_second": 0.486,
      "step": 400
    },
    {
      "epoch": 0.047659898961014205,
      "grad_norm": 2.379204750061035,
      "learning_rate": 4.920566835064976e-05,
      "loss": 1.8513,
      "step": 500
    },
    {
      "epoch": 0.057191878753217046,
      "eval_accuracy": 0.7487254293909154,
      "eval_loss": 1.188010334968567,
      "eval_runtime": 1128.193,
      "eval_samples_per_second": 15.517,
      "eval_steps_per_second": 0.486,
      "step": 600
    },
    {
      "epoch": 0.07625583833762273,
      "eval_accuracy": 0.7630523662181098,
      "eval_loss": 1.1084955930709839,
      "eval_runtime": 1128.3934,
      "eval_samples_per_second": 15.514,
      "eval_steps_per_second": 0.486,
      "step": 800
    },
    {
      "epoch": 0.09531979792202841,
      "grad_norm": 2.218456268310547,
      "learning_rate": 4.841133670129953e-05,
      "loss": 1.1387,
      "step": 1000
    },
    {
      "epoch": 0.09531979792202841,
      "eval_accuracy": 0.7720419453759662,
      "eval_loss": 1.057796597480774,
      "eval_runtime": 1128.1566,
      "eval_samples_per_second": 15.517,
      "eval_steps_per_second": 0.486,
      "step": 1000
    },
    {
      "epoch": 0.11438375750643409,
      "eval_accuracy": 0.7792805618298705,
      "eval_loss": 1.0198323726654053,
      "eval_runtime": 1128.4409,
      "eval_samples_per_second": 15.513,
      "eval_steps_per_second": 0.486,
      "step": 1200
    },
    {
      "epoch": 0.13344771709083977,
      "eval_accuracy": 0.7836537788805386,
      "eval_loss": 0.9978336691856384,
      "eval_runtime": 1127.624,
      "eval_samples_per_second": 15.525,
      "eval_steps_per_second": 0.486,
      "step": 1400
    },
    {
      "epoch": 0.1429796968830426,
      "grad_norm": 2.3090548515319824,
      "learning_rate": 4.761700505194929e-05,
      "loss": 1.0151,
      "step": 1500
    },
    {
      "epoch": 0.15251167667524546,
      "eval_accuracy": 0.7889919141146797,
      "eval_loss": 0.9722086191177368,
      "eval_runtime": 1128.0241,
      "eval_samples_per_second": 15.519,
      "eval_steps_per_second": 0.486,
      "step": 1600
    },
    {
      "epoch": 0.17157563625965114,
      "eval_accuracy": 0.7922293997022891,
      "eval_loss": 0.9535930156707764,
      "eval_runtime": 1128.3297,
      "eval_samples_per_second": 15.515,
      "eval_steps_per_second": 0.486,
      "step": 1800
    },
    {
      "epoch": 0.19063959584405682,
      "grad_norm": 2.6724276542663574,
      "learning_rate": 4.682267340259906e-05,
      "loss": 0.9603,
      "step": 2000
    },
    {
      "epoch": 0.19063959584405682,
      "eval_accuracy": 0.7961234680845941,
      "eval_loss": 0.9353302121162415,
      "eval_runtime": 1128.8643,
      "eval_samples_per_second": 15.508,
      "eval_steps_per_second": 0.485,
      "step": 2000
    },
    {
      "epoch": 0.19063959584405682,
      "step": 2000,
      "total_flos": 1.483774567120896e+18,
      "train_loss": 1.24136767578125,
      "train_runtime": 24979.2484,
      "train_samples_per_second": 40.319,
      "train_steps_per_second": 1.26
    }
  ],
  "logging_steps": 500,
  "max_steps": 31473,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 1000,
  "total_flos": 1.483774567120896e+18,
  "train_batch_size": 32,
  "trial_name": None,
  "trial_params": None
}

# %%
# Visualize the training progress
import matplotlib.pyplot as plt
#plot te eval_loss and eval_accuracy for each log_history entry, have the x-axis be the step number

eval_loss_llama_en = [log['eval_loss'] for log in llama_en_mntp_da['log_history'] if 'eval_loss' in log]
eval_accuracy_llama_en = [log['eval_accuracy'] for log in llama_en_mntp_da['log_history'] if 'eval_accuracy' in log]

eval_loss_llama_en_llm2vec = [log['eval_loss'] for log in llama_en_mntp_en['log_history'] if 'eval_loss' in log]
eval_accuracy_llama_en_llm2vec = [log['eval_accuracy'] for log in llama_en_mntp_en['log_history'] if 'eval_accuracy' in log]

eval_loss_llama_swe = [log['eval_loss'] for log in llama_swe_mntp_da['log_history'] if 'eval_loss' in log]
eval_accuracy_llama_swe = [log['eval_accuracy'] for log in llama_swe_mntp_da['log_history'] if 'eval_accuracy' in log]

eval_loss_llama_swe_long_train = [log['eval_loss'] for log in llama_swe_mntp_da_long_train['log_history'] if 'eval_loss' in log]
eval_accuracy_llama_swe_long_train = [log['eval_accuracy'] for log in llama_swe_mntp_da_long_train['log_history'] if 'eval_accuracy' in log]

eval_loss_llama_swe_scandi = [log['eval_loss'] for log in llama_swe_mntp_scandi['log_history'] if 'eval_loss' in log]
eval_accuracy_llama_swe_scandi = [log['eval_accuracy'] for log in llama_swe_mntp_scandi['log_history'] if 'eval_accuracy' in log]

step = [log['step'] for log in llama_en_mntp_da['log_history'] if 'eval_accuracy' in log]
step_long_train = [log['step'] for log in llama_swe_mntp_da_long_train['log_history'] if 'eval_accuracy' in log]
step_scandi = [log['step'] for log in llama_swe_mntp_scandi['log_history'] if 'eval_accuracy' in log]

# %%
len(step)
# Out:
# 10

# %%
#Create a subplot with 2 plots horizontally
# In the one plot add the eval_loss for llama_en_mntp_da and llama_swe_mntp_da
# In the other plot add the eval_accuracy for llama_en_mntp_da and llama_swe_mntp_da
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

axs.plot(step, eval_loss_llama_en, label='llama-en MNTP dk-wiki')
axs.plot(step, eval_loss_llama_swe, label='llama-swe MNTP dk-wiki')
#axs.plot(step, eval_loss_llama_en_llm2vec, label='llama-en MNTP en-wiki')

#axs.plot(step_long_train, eval_loss_llama_swe_long_train, label='llama_swe_mntp_da_long_train')
axs.plot(step_scandi, eval_loss_llama_swe_scandi, label='llama-swe MNTP scandi-wiki')

axs.set_title('Eval Loss, perplexity')
axs.set_xlabel('Step')
axs.set_ylabel('Loss')

axs.plot(step, eval_accuracy_llama_en, label='llama-en MNTP dk-wiki')
axs.plot(step, eval_accuracy_llama_swe, label='llama-swe MNTP dk-wiki')
#axs.plot(step, eval_accuracy_llama_en_llm2vec, label='llama-en MNTP en-wiki')

#axs.plot(step_long_train, eval_accuracy_llama_swe_long_train, label='llama_swe_mntp_da_long_train')
axs.plot(step_scandi, eval_accuracy_llama_swe_scandi, label='llama-swe MNTP scandi-wiki')

axs.set_title('Eval Accuracy')
axs.set_xlabel('Step')
axs.set_ylabel('Accuracy')

#Add legends
axs.legend()
axs.legend()
plt.show()

# %% [markdown]
# ### SimCSE

# %%
llama_swe_mntp_da_simcse_da = {
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 0.08140670791273201,
  "eval_steps": 500,
  "global_step": 1000,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.0040703353956366,
      "grad_norm": 0.23214782774448395,
      "learning_rate": 2.9959296646043635e-05,
      "loss": 1.269,
      "step": 50
    },
    {
      "epoch": 0.0081406707912732,
      "grad_norm": 0.17025896906852722,
      "learning_rate": 2.991859329208727e-05,
      "loss": 0.0142,
      "step": 100
    },
    {
      "epoch": 0.012211006186909802,
      "grad_norm": 0.050446730107069016,
      "learning_rate": 2.98778899381309e-05,
      "loss": 0.0058,
      "step": 150
    },
    {
      "epoch": 0.0162813415825464,
      "grad_norm": 0.1324562430381775,
      "learning_rate": 2.9837186584174535e-05,
      "loss": 0.0061,
      "step": 200
    },
    {
      "epoch": 0.020351676978183002,
      "grad_norm": 0.12791140377521515,
      "learning_rate": 2.979648323021817e-05,
      "loss": 0.0048,
      "step": 250
    },
    {
      "epoch": 0.024422012373819604,
      "grad_norm": 0.09407847374677658,
      "learning_rate": 2.9755779876261804e-05,
      "loss": 0.0053,
      "step": 300
    },
    {
      "epoch": 0.028492347769456205,
      "grad_norm": 0.058730680495500565,
      "learning_rate": 2.971507652230544e-05,
      "loss": 0.0035,
      "step": 350
    },
    {
      "epoch": 0.0325626831650928,
      "grad_norm": 0.024664631113409996,
      "learning_rate": 2.967437316834907e-05,
      "loss": 0.0036,
      "step": 400
    },
    {
      "epoch": 0.036633018560729404,
      "grad_norm": 0.05520161613821983,
      "learning_rate": 2.9633669814392704e-05,
      "loss": 0.0039,
      "step": 450
    },
    {
      "epoch": 0.040703353956366005,
      "grad_norm": 0.004811314400285482,
      "learning_rate": 2.959296646043634e-05,
      "loss": 0.0027,
      "step": 500
    },
    {
      "epoch": 0.044773689352002606,
      "grad_norm": 0.014692900702357292,
      "learning_rate": 2.9552263106479973e-05,
      "loss": 0.0031,
      "step": 550
    },
    {
      "epoch": 0.04884402474763921,
      "grad_norm": 0.016025545075535774,
      "learning_rate": 2.951155975252361e-05,
      "loss": 0.0024,
      "step": 600
    },
    {
      "epoch": 0.05291436014327581,
      "grad_norm": 0.05121972784399986,
      "learning_rate": 2.9470856398567242e-05,
      "loss": 0.0029,
      "step": 650
    },
    {
      "epoch": 0.05698469553891241,
      "grad_norm": 0.03539630025625229,
      "learning_rate": 2.9430153044610877e-05,
      "loss": 0.0028,
      "step": 700
    },
    {
      "epoch": 0.061055030934549004,
      "grad_norm": 0.013808997347950935,
      "learning_rate": 2.938944969065451e-05,
      "loss": 0.0026,
      "step": 750
    },
    {
      "epoch": 0.0651253663301856,
      "grad_norm": 0.05338102951645851,
      "learning_rate": 2.9348746336698146e-05,
      "loss": 0.0024,
      "step": 800
    },
    {
      "epoch": 0.0691957017258222,
      "grad_norm": 0.047340087592601776,
      "learning_rate": 2.930804298274178e-05,
      "loss": 0.0026,
      "step": 850
    },
    {
      "epoch": 0.07326603712145881,
      "grad_norm": 0.010415674187242985,
      "learning_rate": 2.9267339628785415e-05,
      "loss": 0.0023,
      "step": 900
    },
    {
      "epoch": 0.07733637251709541,
      "grad_norm": 0.014117385260760784,
      "learning_rate": 2.9226636274829046e-05,
      "loss": 0.0029,
      "step": 950
    },
    {
      "epoch": 0.08140670791273201,
      "grad_norm": 0.011241593398153782,
      "learning_rate": 2.918593292087268e-05,
      "loss": 0.0022,
      "step": 1000
    }
  ],
  "logging_steps": 50,
  "max_steps": 36852,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 200,
  "total_flos": 0.0,
  "train_batch_size": 128,
  "trial_name": None,
  "trial_params": None
}

# %%
llama_swe_mntp_da_simcse_da_long_train = {
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 0.24422012373819602,
  "eval_steps": 500,
  "global_step": 3000,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.020351676978183002,
      "grad_norm": 0.1307392567396164,
      "learning_rate": 2.979648323021817e-05,
      "loss": 0.2782,
      "step": 250
    },
    {
      "epoch": 0.040703353956366005,
      "grad_norm": 0.004136309027671814,
      "learning_rate": 2.959296646043634e-05,
      "loss": 0.0038,
      "step": 500
    },
    {
      "epoch": 0.061055030934549004,
      "grad_norm": 0.01469679456204176,
      "learning_rate": 2.938944969065451e-05,
      "loss": 0.0027,
      "step": 750
    },
    {
      "epoch": 0.08140670791273201,
      "grad_norm": 0.3437653183937073,
      "learning_rate": 2.918593292087268e-05,
      "loss": 0.0024,
      "step": 1000
    },
    {
      "epoch": 0.10175838489091502,
      "grad_norm": 0.01950867287814617,
      "learning_rate": 2.898241615109085e-05,
      "loss": 0.0023,
      "step": 1250
    },
    {
      "epoch": 0.12211006186909801,
      "grad_norm": 0.039492689073085785,
      "learning_rate": 2.877889938130902e-05,
      "loss": 0.0019,
      "step": 1500
    },
    {
      "epoch": 0.14246173884728103,
      "grad_norm": 0.0020961714908480644,
      "learning_rate": 2.857538261152719e-05,
      "loss": 0.0018,
      "step": 1750
    },
    {
      "epoch": 0.16281341582546402,
      "grad_norm": 0.010909130796790123,
      "learning_rate": 2.837186584174536e-05,
      "loss": 0.0018,
      "step": 2000
    },
    {
      "epoch": 0.183165092803647,
      "grad_norm": 0.022702300921082497,
      "learning_rate": 2.816834907196353e-05,
      "loss": 0.0016,
      "step": 2250
    },
    {
      "epoch": 0.20351676978183003,
      "grad_norm": 0.017185743898153305,
      "learning_rate": 2.79648323021817e-05,
      "loss": 0.0014,
      "step": 2500
    },
    {
      "epoch": 0.22386844676001302,
      "grad_norm": 0.02063518390059471,
      "learning_rate": 2.7761315532399868e-05,
      "loss": 0.0015,
      "step": 2750
    },
    {
      "epoch": 0.24422012373819602,
      "grad_norm": 0.013097860850393772,
      "learning_rate": 2.755779876261804e-05,
      "loss": 0.0013,
      "step": 3000
    }
  ],
  "logging_steps": 250,
  "max_steps": 36852,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 500,
  "total_flos": 0.0,
  "train_batch_size": 128,
  "trial_name": None,
  "trial_params": None
}

# %%
llama_en_mntp_da_simcse_da = {
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 0.08140670791273201,
  "eval_steps": 500,
  "global_step": 1000,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.0040703353956366,
      "grad_norm": 0.8551507592201233,
      "learning_rate": 2.9959296646043635e-05,
      "loss": 1.8278,
      "step": 50
    },
    {
      "epoch": 0.0081406707912732,
      "grad_norm": 0.6171118021011353,
      "learning_rate": 2.991859329208727e-05,
      "loss": 0.0282,
      "step": 100
    },
    {
      "epoch": 0.012211006186909802,
      "grad_norm": 0.04681049659848213,
      "learning_rate": 2.98778899381309e-05,
      "loss": 0.0061,
      "step": 150
    },
    {
      "epoch": 0.0162813415825464,
      "grad_norm": 0.0864928737282753,
      "learning_rate": 2.9837186584174535e-05,
      "loss": 0.0061,
      "step": 200
    },
    {
      "epoch": 0.020351676978183002,
      "grad_norm": 0.09369981288909912,
      "learning_rate": 2.979648323021817e-05,
      "loss": 0.0048,
      "step": 250
    },
    {
      "epoch": 0.024422012373819604,
      "grad_norm": 0.05656412988901138,
      "learning_rate": 2.9755779876261804e-05,
      "loss": 0.0044,
      "step": 300
    },
    {
      "epoch": 0.028492347769456205,
      "grad_norm": 0.06424488872289658,
      "learning_rate": 2.971507652230544e-05,
      "loss": 0.0033,
      "step": 350
    },
    {
      "epoch": 0.0325626831650928,
      "grad_norm": 0.028317060321569443,
      "learning_rate": 2.967437316834907e-05,
      "loss": 0.0034,
      "step": 400
    },
    {
      "epoch": 0.036633018560729404,
      "grad_norm": 0.03844854235649109,
      "learning_rate": 2.9633669814392704e-05,
      "loss": 0.0036,
      "step": 450
    },
    {
      "epoch": 0.040703353956366005,
      "grad_norm": 0.013333266600966454,
      "learning_rate": 2.959296646043634e-05,
      "loss": 0.0026,
      "step": 500
    },
    {
      "epoch": 0.044773689352002606,
      "grad_norm": 0.027189180254936218,
      "learning_rate": 2.9552263106479973e-05,
      "loss": 0.0027,
      "step": 550
    },
    {
      "epoch": 0.04884402474763921,
      "grad_norm": 0.015432504937052727,
      "learning_rate": 2.951155975252361e-05,
      "loss": 0.0021,
      "step": 600
    },
    {
      "epoch": 0.05291436014327581,
      "grad_norm": 0.0909409150481224,
      "learning_rate": 2.9470856398567242e-05,
      "loss": 0.0028,
      "step": 650
    },
    {
      "epoch": 0.05698469553891241,
      "grad_norm": 0.03523814678192139,
      "learning_rate": 2.9430153044610877e-05,
      "loss": 0.0027,
      "step": 700
    },
    {
      "epoch": 0.061055030934549004,
      "grad_norm": 0.037610672414302826,
      "learning_rate": 2.938944969065451e-05,
      "loss": 0.0025,
      "step": 750
    },
    {
      "epoch": 0.0651253663301856,
      "grad_norm": 0.03404204174876213,
      "learning_rate": 2.9348746336698146e-05,
      "loss": 0.0023,
      "step": 800
    },
    {
      "epoch": 0.0691957017258222,
      "grad_norm": 0.0387328565120697,
      "learning_rate": 2.930804298274178e-05,
      "loss": 0.0023,
      "step": 850
    },
    {
      "epoch": 0.07326603712145881,
      "grad_norm": 0.017468873411417007,
      "learning_rate": 2.9267339628785415e-05,
      "loss": 0.0023,
      "step": 900
    },
    {
      "epoch": 0.07733637251709541,
      "grad_norm": 0.025613853707909584,
      "learning_rate": 2.9226636274829046e-05,
      "loss": 0.003,
      "step": 950
    },
    {
      "epoch": 0.08140670791273201,
      "grad_norm": 0.020182810723781586,
      "learning_rate": 2.918593292087268e-05,
      "loss": 0.002,
      "step": 1000
    }
  ],
  "logging_steps": 50,
  "max_steps": 36852,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 200,
  "total_flos": 0.0,
  "train_batch_size": 128,
  "trial_name": None,
  "trial_params": None
}

# %%
llama_swe_mntp_da_simcse_scandi = {
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 0.2559836170485089,
  "eval_steps": 500,
  "global_step": 2000,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.031997952131063614,
      "grad_norm": 0.06517554074525833,
      "learning_rate": 2.9680020478689362e-05,
      "loss": 0.2761,
      "step": 250
    },
    {
      "epoch": 0.06399590426212723,
      "grad_norm": 0.05590095743536949,
      "learning_rate": 2.936004095737873e-05,
      "loss": 0.0085,
      "step": 500
    },
    {
      "epoch": 0.09599385639319083,
      "grad_norm": 0.06787142902612686,
      "learning_rate": 2.9040061436068092e-05,
      "loss": 0.007,
      "step": 750
    },
    {
      "epoch": 0.12799180852425446,
      "grad_norm": 0.019182974472641945,
      "learning_rate": 2.8720081914757454e-05,
      "loss": 0.0063,
      "step": 1000
    },
    {
      "epoch": 0.15998976065531806,
      "grad_norm": 0.02994903363287449,
      "learning_rate": 2.840010239344682e-05,
      "loss": 0.0056,
      "step": 1250
    },
    {
      "epoch": 0.19198771278638166,
      "grad_norm": 0.016078654676675797,
      "learning_rate": 2.8080122872136184e-05,
      "loss": 0.0056,
      "step": 1500
    },
    {
      "epoch": 0.2239856649174453,
      "grad_norm": 0.0162887554615736,
      "learning_rate": 2.776014335082555e-05,
      "loss": 0.0051,
      "step": 1750
    },
    {
      "epoch": 0.2559836170485089,
      "grad_norm": 0.024330032989382744,
      "learning_rate": 2.744016382951491e-05,
      "loss": 0.0053,
      "step": 2000
    }
  ],
  "logging_steps": 250,
  "max_steps": 23439,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 500,
  "total_flos": 0.0,
  "train_batch_size": 128,
  "trial_name": None,
  "trial_params": None
}

# %%
# Scandi-wiki MNTP 2000 steps, then Scandi-wiki SimCSE 2000 steps
llama_swe_mntp_scandi_simcse_scandi_2000 = {
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 0.2559836170485089,
  "eval_steps": 500,
  "global_step": 2000,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.006399590426212722,
      "grad_norm": 2.019897222518921,
      "learning_rate": 2.9936004095737874e-05,
      "loss": 1.316,
      "step": 50
    },
    {
      "epoch": 0.012799180852425445,
      "grad_norm": 0.027188843116164207,
      "learning_rate": 2.9872008191475745e-05,
      "loss": 0.0257,
      "step": 100
    },
    {
      "epoch": 0.019198771278638168,
      "grad_norm": 0.11125721782445908,
      "learning_rate": 2.980801228721362e-05,
      "loss": 0.0146,
      "step": 150
    },
    {
      "epoch": 0.02559836170485089,
      "grad_norm": 0.06378450989723206,
      "learning_rate": 2.9744016382951492e-05,
      "loss": 0.0099,
      "step": 200
    },
    {
      "epoch": 0.031997952131063614,
      "grad_norm": 0.06517554074525833,
      "learning_rate": 2.9680020478689362e-05,
      "loss": 0.0142,
      "step": 250
    },
    {
      "epoch": 0.038397542557276336,
      "grad_norm": 0.051223862916231155,
      "learning_rate": 2.9616024574427236e-05,
      "loss": 0.0094,
      "step": 300
    },
    {
      "epoch": 0.04479713298348906,
      "grad_norm": 0.010927141644060612,
      "learning_rate": 2.955202867016511e-05,
      "loss": 0.0076,
      "step": 350
    },
    {
      "epoch": 0.05119672340970178,
      "grad_norm": 0.02487807907164097,
      "learning_rate": 2.948803276590298e-05,
      "loss": 0.0084,
      "step": 400
    },
    {
      "epoch": 0.0575963138359145,
      "grad_norm": 0.021612701937556267,
      "learning_rate": 2.9424036861640857e-05,
      "loss": 0.0078,
      "step": 450
    },
    {
      "epoch": 0.06399590426212723,
      "grad_norm": 0.05590095743536949,
      "learning_rate": 2.936004095737873e-05,
      "loss": 0.0095,
      "step": 500
    },
    {
      "epoch": 0.07039549468833994,
      "grad_norm": 0.014129425399005413,
      "learning_rate": 2.92960450531166e-05,
      "loss": 0.0078,
      "step": 550
    },
    {
      "epoch": 0.07679508511455267,
      "grad_norm": 0.04248964414000511,
      "learning_rate": 2.9232049148854475e-05,
      "loss": 0.0073,
      "step": 600
    },
    {
      "epoch": 0.08319467554076539,
      "grad_norm": 0.07960448414087296,
      "learning_rate": 2.916805324459235e-05,
      "loss": 0.0064,
      "step": 650
    },
    {
      "epoch": 0.08959426596697811,
      "grad_norm": 0.03152291849255562,
      "learning_rate": 2.910405734033022e-05,
      "loss": 0.0063,
      "step": 700
    },
    {
      "epoch": 0.09599385639319083,
      "grad_norm": 0.06787142902612686,
      "learning_rate": 2.9040061436068092e-05,
      "loss": 0.0074,
      "step": 750
    },
    {
      "epoch": 0.10239344681940356,
      "grad_norm": 0.0437660776078701,
      "learning_rate": 2.8976065531805966e-05,
      "loss": 0.0055,
      "step": 800
    },
    {
      "epoch": 0.10879303724561629,
      "grad_norm": 0.042677707970142365,
      "learning_rate": 2.8912069627543836e-05,
      "loss": 0.0071,
      "step": 850
    },
    {
      "epoch": 0.115192627671829,
      "grad_norm": 0.0232229121029377,
      "learning_rate": 2.884807372328171e-05,
      "loss": 0.0074,
      "step": 900
    },
    {
      "epoch": 0.12159221809804173,
      "grad_norm": 0.025392193347215652,
      "learning_rate": 2.8784077819019584e-05,
      "loss": 0.0052,
      "step": 950
    },
    {
      "epoch": 0.12799180852425446,
      "grad_norm": 0.019182974472641945,
      "learning_rate": 2.8720081914757454e-05,
      "loss": 0.0065,
      "step": 1000
    },
    {
      "epoch": 0.13439139895046717,
      "grad_norm": 0.050012364983558655,
      "learning_rate": 2.8656086010495328e-05,
      "loss": 0.0048,
      "step": 1050
    },
    {
      "epoch": 0.1407909893766799,
      "grad_norm": 0.0185084268450737,
      "learning_rate": 2.85920901062332e-05,
      "loss": 0.0063,
      "step": 1100
    },
    {
      "epoch": 0.1471905798028926,
      "grad_norm": 0.01222296990454197,
      "learning_rate": 2.8528094201971072e-05,
      "loss": 0.0052,
      "step": 1150
    },
    {
      "epoch": 0.15359017022910534,
      "grad_norm": 0.05517255887389183,
      "learning_rate": 2.8464098297708945e-05,
      "loss": 0.0063,
      "step": 1200
    },
    {
      "epoch": 0.15998976065531806,
      "grad_norm": 0.02994903363287449,
      "learning_rate": 2.840010239344682e-05,
      "loss": 0.0054,
      "step": 1250
    },
    {
      "epoch": 0.16638935108153077,
      "grad_norm": 0.009264162741601467,
      "learning_rate": 2.8336106489184693e-05,
      "loss": 0.0065,
      "step": 1300
    },
    {
      "epoch": 0.17278894150774352,
      "grad_norm": 0.020964695140719414,
      "learning_rate": 2.8272110584922566e-05,
      "loss": 0.0058,
      "step": 1350
    },
    {
      "epoch": 0.17918853193395623,
      "grad_norm": 0.03918587043881416,
      "learning_rate": 2.820811468066044e-05,
      "loss": 0.0055,
      "step": 1400
    },
    {
      "epoch": 0.18558812236016894,
      "grad_norm": 0.02605220302939415,
      "learning_rate": 2.814411877639831e-05,
      "loss": 0.0049,
      "step": 1450
    },
    {
      "epoch": 0.19198771278638166,
      "grad_norm": 0.016078654676675797,
      "learning_rate": 2.8080122872136184e-05,
      "loss": 0.0052,
      "step": 1500
    },
    {
      "epoch": 0.1983873032125944,
      "grad_norm": 0.013056494295597076,
      "learning_rate": 2.8016126967874058e-05,
      "loss": 0.0047,
      "step": 1550
    },
    {
      "epoch": 0.20478689363880712,
      "grad_norm": 0.0374971479177475,
      "learning_rate": 2.795213106361193e-05,
      "loss": 0.0059,
      "step": 1600
    },
    {
      "epoch": 0.21118648406501983,
      "grad_norm": 0.01646304503083229,
      "learning_rate": 2.7888135159349802e-05,
      "loss": 0.0057,
      "step": 1650
    },
    {
      "epoch": 0.21758607449123257,
      "grad_norm": 0.03833327069878578,
      "learning_rate": 2.7824139255087675e-05,
      "loss": 0.0033,
      "step": 1700
    },
    {
      "epoch": 0.2239856649174453,
      "grad_norm": 0.0162887554615736,
      "learning_rate": 2.776014335082555e-05,
      "loss": 0.0058,
      "step": 1750
    },
    {
      "epoch": 0.230385255343658,
      "grad_norm": 0.025559017434716225,
      "learning_rate": 2.769614744656342e-05,
      "loss": 0.005,
      "step": 1800
    },
    {
      "epoch": 0.23678484576987072,
      "grad_norm": 0.018275156617164612,
      "learning_rate": 2.7632151542301293e-05,
      "loss": 0.0061,
      "step": 1850
    },
    {
      "epoch": 0.24318443619608346,
      "grad_norm": 0.01494657900184393,
      "learning_rate": 2.7568155638039167e-05,
      "loss": 0.005,
      "step": 1900
    },
    {
      "epoch": 0.24958402662229617,
      "grad_norm": 0.009650061838328838,
      "learning_rate": 2.7504159733777037e-05,
      "loss": 0.004,
      "step": 1950
    },
    {
      "epoch": 0.2559836170485089,
      "grad_norm": 0.024330032989382744,
      "learning_rate": 2.744016382951491e-05,
      "loss": 0.0062,
      "step": 2000
    }
  ],
  "logging_steps": 50,
  "max_steps": 23439,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 1000,
  "total_flos": 0.0,
  "train_batch_size": 128,
  "trial_name": None,
  "trial_params": None
}

# %%
# Intention to further finetune on DK SimCSE model with scandi, but I think it turns out that all I did was finetune further on the DK MNTP model!
llama_swe_mntp_dk_scandi_simcse_by_mistake = {
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 0.12799180852425446,
  "eval_steps": 500,
  "global_step": 1000,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.006399590426212722,
      "grad_norm": 0.06757518649101257,
      "learning_rate": 2.9936004095737874e-05,
      "loss": 0.3069,
      "step": 50
    },
    {
      "epoch": 0.012799180852425445,
      "grad_norm": 0.0033132547978311777,
      "learning_rate": 2.9872008191475745e-05,
      "loss": 0.0072,
      "step": 100
    },
    {
      "epoch": 0.019198771278638168,
      "grad_norm": 0.02232983522117138,
      "learning_rate": 2.980801228721362e-05,
      "loss": 0.0068,
      "step": 150
    },
    {
      "epoch": 0.02559836170485089,
      "grad_norm": 0.01696196012198925,
      "learning_rate": 2.9744016382951492e-05,
      "loss": 0.0045,
      "step": 200
    },
    {
      "epoch": 0.031997952131063614,
      "grad_norm": 0.00927664339542389,
      "learning_rate": 2.9680020478689362e-05,
      "loss": 0.0095,
      "step": 250
    },
    {
      "epoch": 0.038397542557276336,
      "grad_norm": 0.013083786703646183,
      "learning_rate": 2.9616024574427236e-05,
      "loss": 0.0059,
      "step": 300
    },
    {
      "epoch": 0.04479713298348906,
      "grad_norm": 0.0031430176459252834,
      "learning_rate": 2.955202867016511e-05,
      "loss": 0.0056,
      "step": 350
    },
    {
      "epoch": 0.05119672340970178,
      "grad_norm": 0.003768143244087696,
      "learning_rate": 2.948803276590298e-05,
      "loss": 0.0059,
      "step": 400
    },
    {
      "epoch": 0.0575963138359145,
      "grad_norm": 0.006923678796738386,
      "learning_rate": 2.9424036861640857e-05,
      "loss": 0.0058,
      "step": 450
    },
    {
      "epoch": 0.06399590426212723,
      "grad_norm": 0.03355035558342934,
      "learning_rate": 2.936004095737873e-05,
      "loss": 0.0077,
      "step": 500
    },
    {
      "epoch": 0.07039549468833994,
      "grad_norm": 0.0059617324732244015,
      "learning_rate": 2.92960450531166e-05,
      "loss": 0.0063,
      "step": 550
    },
    {
      "epoch": 0.07679508511455267,
      "grad_norm": 0.023468513041734695,
      "learning_rate": 2.9232049148854475e-05,
      "loss": 0.0061,
      "step": 600
    },
    {
      "epoch": 0.08319467554076539,
      "grad_norm": 0.03374939784407616,
      "learning_rate": 2.916805324459235e-05,
      "loss": 0.0054,
      "step": 650
    },
    {
      "epoch": 0.08959426596697811,
      "grad_norm": 0.015217668376863003,
      "learning_rate": 2.910405734033022e-05,
      "loss": 0.0053,
      "step": 700
    },
    {
      "epoch": 0.09599385639319083,
      "grad_norm": 0.01654445379972458,
      "learning_rate": 2.9040061436068092e-05,
      "loss": 0.0063,
      "step": 750
    },
    {
      "epoch": 0.10239344681940356,
      "grad_norm": 0.015822233632206917,
      "learning_rate": 2.8976065531805966e-05,
      "loss": 0.0047,
      "step": 800
    },
    {
      "epoch": 0.10879303724561629,
      "grad_norm": 0.016861580312252045,
      "learning_rate": 2.8912069627543836e-05,
      "loss": 0.0063,
      "step": 850
    },
    {
      "epoch": 0.115192627671829,
      "grad_norm": 0.009029300883412361,
      "learning_rate": 2.884807372328171e-05,
      "loss": 0.0064,
      "step": 900
    },
    {
      "epoch": 0.12159221809804173,
      "grad_norm": 0.01570909656584263,
      "learning_rate": 2.8784077819019584e-05,
      "loss": 0.0043,
      "step": 950
    },
    {
      "epoch": 0.12799180852425446,
      "grad_norm": 0.00807859655469656,
      "learning_rate": 2.8720081914757454e-05,
      "loss": 0.0054,
      "step": 1000
    }
  ],
  "logging_steps": 50,
  "max_steps": 23439,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 250,
  "total_flos": 0.0,
  "train_batch_size": 128,
  "trial_name": None,
  "trial_params": None
}

# %%
llama_swe_mntp_scandi_simcse_scandi = {
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 0.12799180852425446,
  "eval_steps": 500,
  "global_step": 1000,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.012799180852425445,
      "grad_norm": 0.03587488457560539,
      "learning_rate": 2.9872008191475745e-05,
      "loss": 0.6699,
      "step": 100
    },
    {
      "epoch": 0.02559836170485089,
      "grad_norm": 0.06743154674768448,
      "learning_rate": 2.9744016382951492e-05,
      "loss": 0.0124,
      "step": 200
    },
    {
      "epoch": 0.038397542557276336,
      "grad_norm": 0.04106317088007927,
      "learning_rate": 2.9616024574427236e-05,
      "loss": 0.012,
      "step": 300
    },
    {
      "epoch": 0.05119672340970178,
      "grad_norm": 0.0331423245370388,
      "learning_rate": 2.948803276590298e-05,
      "loss": 0.0083,
      "step": 400
    },
    {
      "epoch": 0.06399590426212723,
      "grad_norm": 0.05251430347561836,
      "learning_rate": 2.936004095737873e-05,
      "loss": 0.0092,
      "step": 500
    },
    {
      "epoch": 0.07679508511455267,
      "grad_norm": 0.04744878038764,
      "learning_rate": 2.9232049148854475e-05,
      "loss": 0.0081,
      "step": 600
    },
    {
      "epoch": 0.08959426596697811,
      "grad_norm": 0.03209812939167023,
      "learning_rate": 2.910405734033022e-05,
      "loss": 0.0067,
      "step": 700
    },
    {
      "epoch": 0.10239344681940356,
      "grad_norm": 0.03629107400774956,
      "learning_rate": 2.8976065531805966e-05,
      "loss": 0.0067,
      "step": 800
    },
    {
      "epoch": 0.115192627671829,
      "grad_norm": 0.02547544240951538,
      "learning_rate": 2.884807372328171e-05,
      "loss": 0.0075,
      "step": 900
    },
    {
      "epoch": 0.12799180852425446,
      "grad_norm": 0.01609966531395912,
      "learning_rate": 2.8720081914757454e-05,
      "loss": 0.0061,
      "step": 1000
    }
  ],
  "logging_steps": 100,
  "max_steps": 23439,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 500,
  "total_flos": 0.0,
  "train_batch_size": 128,
  "trial_name": None,
  "trial_params": None
}

# %%
# Visualize the training progress of the simcse using the loss
# Visualize the training progress
import matplotlib.pyplot as plt

# Llama-swe MNTP 1k on WikiDK then SimCSE 1k on WikiDK
loss_llama_swe_simcse = [log['loss'] for log in llama_swe_mntp_da_simcse_da['log_history'] if 'loss' in log]
step = [log['step'] for log in llama_swe_mntp_da_simcse_da['log_history'] if 'loss' in log]

# Llama-en MNTP 1k on WikiDK then SimCSE 1k on WikiDK
loss_llama_en_simcse = [log['loss'] for log in llama_en_mntp_da_simcse_da['log_history'] if 'loss' in log]

# Llama-swe MNTP 1k on WikiDK then SimCSE 1K on Wiki Scandi (Intention was to continue training on top of DK SimCSE model, but I had configured PEFT wrong)
llama_swe_mntp_dk_scandi_simcse = [log['loss'] for log in llama_swe_mntp_dk_scandi_simcse_by_mistake['log_history'] if 'loss' in log]
step_dk_scandi = [log['step'] for log in llama_swe_mntp_dk_scandi_simcse_by_mistake['log_history'] if 'loss' in log]

# Llama-swe MNTP 2k on Wiki Scandi then SimCSE 2k on Wiki Scandi
llama_swe_mntp_simcse_scandi_detailed = [log['loss'] for log in llama_swe_mntp_scandi_simcse_scandi_2000['log_history'] if 'loss' in log]
step_scandi_detailed = [log['step'] for log in llama_swe_mntp_scandi_simcse_scandi_2000['log_history'] if 'loss' in log]

# Llama-swe MNTP 1k on Wiki Scandi then SimCSE 1K on Wiki Scandi
llama_swe_mntp_scandi_simcse_scandi_loss = [log['loss'] for log in llama_swe_mntp_scandi_simcse_scandi['log_history'] if 'loss' in log]
llama_swe_mntp_scandi_simcse_scandi_step = [log['step'] for log in llama_swe_mntp_scandi_simcse_scandi['log_history'] if 'loss' in log]
 
# llama_swe_mntp_simcse_scandi = [log['loss'] for log in llama_swe_mntp_da_simcse_scandi['log_history'] if 'loss' in log]
#step_scandi = [log['step'] for log in llama_swe_mntp_da_simcse_scandi['log_history'] if 'loss' in log]

#loss_llama_swe_simcse_long_train = [log['loss'] for log in llama_swe_mntp_simcse_da_long_train['log_history'] if 'loss' in log]
#step_long_train = [log['step'] for log in llama_swe_mntp_simcse_da_long_train['log_history'] if 'loss' in log]

fig, axs = plt.subplots(1, 2, figsize=(12, 5))
axs.plot(step, loss_llama_en_simcse, label='llama_en-1k-dk-1k-dk')
axs.plot(step, loss_llama_swe_simcse, label='llama_swe-1k-dk-1k-dk')
axs.plot(step_dk_scandi, llama_swe_mntp_dk_scandi_simcse, label='llama_swe-1k-dk-1k-scandi') #(SOTA by mistake)
axs.plot(llama_swe_mntp_scandi_simcse_scandi_step, llama_swe_mntp_scandi_simcse_scandi_loss, label='llama_swe-1k-scandi-1k-scandi')
axs.plot(step_scandi_detailed, llama_swe_mntp_simcse_scandi_detailed, label='llama_swe-2k-scandi-2k-scandi')

#axs.plot(step_long_train, loss_llama_swe_simcse_long_train, label='llama_swe_mntp_simcse_da_long_train')
#axs.plot(step_scandi, llama_swe_mntp_simcse_scandi, label='Simcse-scandi-wiki (0.25 epoch)') #poor resolution

axs.set_title('Contrastive Loss')
axs.set_xlabel('Step')
axs.set_ylabel('Loss')
axs.set_ylim(0, 1)

axs.plot(step, loss_llama_en_simcse, label='llama_en-1k-dk-1k-dk')
axs.plot(step, loss_llama_swe_simcse, label='llama_swe-1k-dk-1k-dk')
axs.plot(step_dk_scandi, llama_swe_mntp_dk_scandi_simcse, label='llama_swe-1k-dk-1k-scandi') #SOTA by mistake
axs.plot(llama_swe_mntp_scandi_simcse_scandi_step, llama_swe_mntp_scandi_simcse_scandi_loss, label='llama_swe-1k-scandi-1k-scandi')
axs.plot(step_scandi_detailed, llama_swe_mntp_simcse_scandi_detailed, label='llama_swe-2k-scandi-2k-scandi')
#axs.plot(step_long_train, loss_llama_swe_simcse_long_train, label='llama_swe_mntp_simcse_da_long_train')
#axs.plot(step_scandi, llama_swe_mntp_simcse_scandi, label='Simcse-scandi-wiki (0.25 epoch)') #poor resolution

axs.set_title('Contrastive Loss (zoomed in)')
axs.set_xlabel('Step')
axs.set_ylabel('Loss')
axs.set_ylim(0, 0.03)

#Add legends place them in top right
axs.legend(loc='upper right')
axs.legend(loc='upper right')
plt.show()

# %%
# Visualize the training progress of the simcse using the loss
# Visualize the training progress
import matplotlib.pyplot as plt

# Llama-swe MNTP 1k on WikiDK then SimCSE 1k on WikiDK
loss_llama_swe_simcse = [log['loss'] for log in llama_swe_mntp_da_simcse_da['log_history'] if 'loss' in log]
step = [log['step'] for log in llama_swe_mntp_da_simcse_da['log_history'] if 'loss' in log]

# Llama-en MNTP 1k on WikiDK then SimCSE 1k on WikiDK
loss_llama_en_simcse = [log['loss'] for log in llama_en_mntp_da_simcse_da['log_history'] if 'loss' in log]

# Llama-swe MNTP 1k on WikiDK then SimCSE 1K on Wiki Scandi (Intention was to continue training on top of DK SimCSE model, but I had configured PEFT wrong)
llama_swe_mntp_dk_scandi_simcse = [log['loss'] for log in llama_swe_mntp_dk_scandi_simcse_by_mistake['log_history'] if 'loss' in log]
step_dk_scandi = [log['step'] for log in llama_swe_mntp_dk_scandi_simcse_by_mistake['log_history'] if 'loss' in log]

# Llama-swe MNTP 2k on Wiki Scandi then SimCSE 2k on Wiki Scandi
llama_swe_mntp_simcse_scandi_detailed = [log['loss'] for log in llama_swe_mntp_scandi_simcse_scandi_2000['log_history'] if 'loss' in log]
step_scandi_detailed = [log['step'] for log in llama_swe_mntp_scandi_simcse_scandi_2000['log_history'] if 'loss' in log]

# Llama-swe MNTP 1k on Wiki Scandi then SimCSE 1K on Wiki Scandi
llama_swe_mntp_scandi_simcse_scandi_loss = [log['loss'] for log in llama_swe_mntp_scandi_simcse_scandi['log_history'] if 'loss' in log]
llama_swe_mntp_scandi_simcse_scandi_step = [log['step'] for log in llama_swe_mntp_scandi_simcse_scandi['log_history'] if 'loss' in log]
 
# llama_swe_mntp_simcse_scandi = [log['loss'] for log in llama_swe_mntp_da_simcse_scandi['log_history'] if 'loss' in log]
#step_scandi = [log['step'] for log in llama_swe_mntp_da_simcse_scandi['log_history'] if 'loss' in log]

#loss_llama_swe_simcse_long_train = [log['loss'] for log in llama_swe_mntp_simcse_da_long_train['log_history'] if 'loss' in log]
#step_long_train = [log['step'] for log in llama_swe_mntp_simcse_da_long_train['log_history'] if 'loss' in log]

fig, axs = plt.subplots(1, 1, figsize=(8, 5))
axs.plot(step, loss_llama_en_simcse, label='llama_en-1k-dk-1k-dk')
axs.plot(step, loss_llama_swe_simcse, label='llama_swe-1k-dk-1k-dk')
axs.plot(step_dk_scandi, llama_swe_mntp_dk_scandi_simcse, label='llama_swe-1k-dk-1k-scandi') #SOTA by mistake
axs.plot(llama_swe_mntp_scandi_simcse_scandi_step, llama_swe_mntp_scandi_simcse_scandi_loss, label='llama_swe-1k-scandi-1k-scandi')
axs.plot(step_scandi_detailed, llama_swe_mntp_simcse_scandi_detailed, label='llama_swe-2k-scandi-2k-scandi')
#axs.plot(step_long_train, loss_llama_swe_simcse_long_train, label='llama_swe_mntp_simcse_da_long_train')
#axs.plot(step_scandi, llama_swe_mntp_simcse_scandi, label='Simcse-scandi-wiki (0.25 epoch)') #poor resolution

axs.set_title('Contrastive Loss (zoomed in)')
axs.set_xlabel('Step')
axs.set_ylabel('Loss')
axs.set_ylim(0, 0.03)

#Add legends place them in top right
axs.legend(loc='upper right')
plt.show()

# %% [markdown]
# ### Supervised

# %%
llama_swe_mntp_simcse_supervised_wiki_150 = {
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 2.542372881355932,
  "eval_steps": 500,
  "global_step": 150,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.0847457627118644,
      "grad_norm": 5.159055233001709,
      "learning_rate": 3.3333333333333333e-06,
      "loss": 0.3363,
      "step": 5
    },
    {
      "epoch": 0.1694915254237288,
      "grad_norm": 3.0858068466186523,
      "learning_rate": 6.666666666666667e-06,
      "loss": 0.3158,
      "step": 10
    },
    {
      "epoch": 0.2542372881355932,
      "grad_norm": 1.8810569047927856,
      "learning_rate": 1e-05,
      "loss": 0.3053,
      "step": 15
    },
    {
      "epoch": 0.3389830508474576,
      "grad_norm": 1.4383584260940552,
      "learning_rate": 1.3333333333333333e-05,
      "loss": 0.262,
      "step": 20
    },
    {
      "epoch": 0.423728813559322,
      "grad_norm": 1.2685976028442383,
      "learning_rate": 1.6666666666666667e-05,
      "loss": 0.1876,
      "step": 25
    },
    {
      "epoch": 0.5084745762711864,
      "grad_norm": 0.9680385589599609,
      "learning_rate": 2e-05,
      "loss": 0.1628,
      "step": 30
    },
    {
      "epoch": 0.5932203389830508,
      "grad_norm": 0.9813632965087891,
      "learning_rate": 2.3333333333333336e-05,
      "loss": 0.1334,
      "step": 35
    },
    {
      "epoch": 0.6779661016949152,
      "grad_norm": 0.9503218531608582,
      "learning_rate": 2.6666666666666667e-05,
      "loss": 0.0835,
      "step": 40
    },
    {
      "epoch": 0.7627118644067796,
      "grad_norm": 0.5998983979225159,
      "learning_rate": 3e-05,
      "loss": 0.0837,
      "step": 45
    },
    {
      "epoch": 0.847457627118644,
      "grad_norm": 0.6649953126907349,
      "learning_rate": 3.3333333333333335e-05,
      "loss": 0.0423,
      "step": 50
    },
    {
      "epoch": 0.9322033898305084,
      "grad_norm": 0.9891968965530396,
      "learning_rate": 3.6666666666666666e-05,
      "loss": 0.0663,
      "step": 55
    },
    {
      "epoch": 1.0169491525423728,
      "grad_norm": 0.6218674182891846,
      "learning_rate": 4e-05,
      "loss": 0.0403,
      "step": 60
    },
    {
      "epoch": 1.1016949152542372,
      "grad_norm": 0.7968205213546753,
      "learning_rate": 4.3333333333333334e-05,
      "loss": 0.0395,
      "step": 65
    },
    {
      "epoch": 1.1864406779661016,
      "grad_norm": 0.4469784200191498,
      "learning_rate": 4.666666666666667e-05,
      "loss": 0.0267,
      "step": 70
    },
    {
      "epoch": 1.271186440677966,
      "grad_norm": 0.7213916182518005,
      "learning_rate": 5e-05,
      "loss": 0.0352,
      "step": 75
    },
    {
      "epoch": 1.3559322033898304,
      "grad_norm": 0.4947931170463562,
      "learning_rate": 5.333333333333333e-05,
      "loss": 0.0208,
      "step": 80
    },
    {
      "epoch": 1.4406779661016949,
      "grad_norm": 0.4453703761100769,
      "learning_rate": 5.666666666666667e-05,
      "loss": 0.0201,
      "step": 85
    },
    {
      "epoch": 1.5254237288135593,
      "grad_norm": 0.5589554905891418,
      "learning_rate": 6e-05,
      "loss": 0.0179,
      "step": 90
    },
    {
      "epoch": 1.6101694915254239,
      "grad_norm": 0.5103617310523987,
      "learning_rate": 6.333333333333333e-05,
      "loss": 0.0177,
      "step": 95
    },
    {
      "epoch": 1.694915254237288,
      "grad_norm": 0.5546457171440125,
      "learning_rate": 6.666666666666667e-05,
      "loss": 0.0132,
      "step": 100
    },
    {
      "epoch": 1.7796610169491527,
      "grad_norm": 0.09220392256975174,
      "learning_rate": 7e-05,
      "loss": 0.0074,
      "step": 105
    },
    {
      "epoch": 1.8644067796610169,
      "grad_norm": 0.234584778547287,
      "learning_rate": 7.333333333333333e-05,
      "loss": 0.0069,
      "step": 110
    },
    {
      "epoch": 1.9491525423728815,
      "grad_norm": 0.07510097324848175,
      "learning_rate": 7.666666666666667e-05,
      "loss": 0.0037,
      "step": 115
    },
    {
      "epoch": 2.0338983050847457,
      "grad_norm": 0.0755932554602623,
      "learning_rate": 8e-05,
      "loss": 0.0049,
      "step": 120
    },
    {
      "epoch": 2.1186440677966103,
      "grad_norm": 0.07930958271026611,
      "learning_rate": 8.333333333333334e-05,
      "loss": 0.0023,
      "step": 125
    },
    {
      "epoch": 2.2033898305084745,
      "grad_norm": 0.08583241701126099,
      "learning_rate": 8.666666666666667e-05,
      "loss": 0.002,
      "step": 130
    },
    {
      "epoch": 2.288135593220339,
      "grad_norm": 0.058252207934856415,
      "learning_rate": 9e-05,
      "loss": 0.0012,
      "step": 135
    },
    {
      "epoch": 2.3728813559322033,
      "grad_norm": 0.055956609547138214,
      "learning_rate": 9.333333333333334e-05,
      "loss": 0.0008,
      "step": 140
    },
    {
      "epoch": 2.457627118644068,
      "grad_norm": 0.13208800554275513,
      "learning_rate": 9.666666666666667e-05,
      "loss": 0.0015,
      "step": 145
    },
    {
      "epoch": 2.542372881355932,
      "grad_norm": 0.030882351100444794,
      "learning_rate": 0.0001,
      "loss": 0.001,
      "step": 150
    }
  ],
  "logging_steps": 5,
  "max_steps": 177,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 10,
  "total_flos": 0.0,
  "train_batch_size": 128,
  "trial_name": None,
  "trial_params": None
}

# %%
llama_swe_mntp_simcse_supervised_dkmix_500 ={
  "best_metric": None,
  "best_model_checkpoint": None,
  "epoch": 2.7472527472527473,
  "eval_steps": 500,
  "global_step": 500,
  "is_hyper_param_search": False,
  "is_local_process_zero": True,
  "is_world_process_zero": True,
  "log_history": [
    {
      "epoch": 0.054945054945054944,
      "grad_norm": 7.214223861694336,
      "learning_rate": 6.666666666666667e-06,
      "loss": 1.2206,
      "step": 10
    },
    {
      "epoch": 0.10989010989010989,
      "grad_norm": 1.9139518737792969,
      "learning_rate": 1.3333333333333333e-05,
      "loss": 0.9332,
      "step": 20
    },
    {
      "epoch": 0.16483516483516483,
      "grad_norm": 1.8469916582107544,
      "learning_rate": 2e-05,
      "loss": 0.6775,
      "step": 30
    },
    {
      "epoch": 0.21978021978021978,
      "grad_norm": 1.5840134620666504,
      "learning_rate": 2.6666666666666667e-05,
      "loss": 0.4775,
      "step": 40
    },
    {
      "epoch": 0.27472527472527475,
      "grad_norm": 1.324249029159546,
      "learning_rate": 3.3333333333333335e-05,
      "loss": 0.3462,
      "step": 50
    },
    {
      "epoch": 0.32967032967032966,
      "grad_norm": 9.703359603881836,
      "learning_rate": 4e-05,
      "loss": 0.2783,
      "step": 60
    },
    {
      "epoch": 0.38461538461538464,
      "grad_norm": 0.7924676537513733,
      "learning_rate": 4.666666666666667e-05,
      "loss": 0.2422,
      "step": 70
    },
    {
      "epoch": 0.43956043956043955,
      "grad_norm": 0.7410662770271301,
      "learning_rate": 5.333333333333333e-05,
      "loss": 0.1935,
      "step": 80
    },
    {
      "epoch": 0.4945054945054945,
      "grad_norm": 0.8206967711448669,
      "learning_rate": 6e-05,
      "loss": 0.1737,
      "step": 90
    },
    {
      "epoch": 0.5494505494505495,
      "grad_norm": 0.7770851254463196,
      "learning_rate": 6.666666666666667e-05,
      "loss": 0.1686,
      "step": 100
    },
    {
      "epoch": 0.6043956043956044,
      "grad_norm": 0.77186119556427,
      "learning_rate": 7.333333333333333e-05,
      "loss": 0.1791,
      "step": 110
    },
    {
      "epoch": 0.6593406593406593,
      "grad_norm": 0.6624640822410583,
      "learning_rate": 8e-05,
      "loss": 0.1631,
      "step": 120
    },
    {
      "epoch": 0.7142857142857143,
      "grad_norm": 0.6289125084877014,
      "learning_rate": 8.666666666666667e-05,
      "loss": 0.1695,
      "step": 130
    },
    {
      "epoch": 0.7692307692307693,
      "grad_norm": 0.7366447448730469,
      "learning_rate": 9.333333333333334e-05,
      "loss": 0.1596,
      "step": 140
    },
    {
      "epoch": 0.8241758241758241,
      "grad_norm": 0.6936759948730469,
      "learning_rate": 0.0001,
      "loss": 0.1742,
      "step": 150
    },
    {
      "epoch": 0.8791208791208791,
      "grad_norm": 0.7598293423652649,
      "learning_rate": 0.00010666666666666667,
      "loss": 0.1555,
      "step": 160
    },
    {
      "epoch": 0.9340659340659341,
      "grad_norm": 0.5829370021820068,
      "learning_rate": 0.00011333333333333334,
      "loss": 0.1495,
      "step": 170
    },
    {
      "epoch": 0.989010989010989,
      "grad_norm": 0.7476902604103088,
      "learning_rate": 0.00012,
      "loss": 0.1413,
      "step": 180
    },
    {
      "epoch": 1.043956043956044,
      "grad_norm": 0.611395537853241,
      "learning_rate": 0.00012666666666666666,
      "loss": 0.1584,
      "step": 190
    },
    {
      "epoch": 1.098901098901099,
      "grad_norm": 0.38252344727516174,
      "learning_rate": 0.00013333333333333334,
      "loss": 0.1274,
      "step": 200
    },
    {
      "epoch": 1.1538461538461537,
      "grad_norm": 0.6068706512451172,
      "learning_rate": 0.00014,
      "loss": 0.119,
      "step": 210
    },
    {
      "epoch": 1.2087912087912087,
      "grad_norm": 0.601772665977478,
      "learning_rate": 0.00014666666666666666,
      "loss": 0.1451,
      "step": 220
    },
    {
      "epoch": 1.2637362637362637,
      "grad_norm": 0.4933900833129883,
      "learning_rate": 0.00015333333333333334,
      "loss": 0.1405,
      "step": 230
    },
    {
      "epoch": 1.3186813186813187,
      "grad_norm": 0.37198406457901,
      "learning_rate": 0.00016,
      "loss": 0.1435,
      "step": 240
    },
    {
      "epoch": 1.3736263736263736,
      "grad_norm": 0.2324627786874771,
      "learning_rate": 0.0001666666666666667,
      "loss": 0.1405,
      "step": 250
    },
    {
      "epoch": 1.4285714285714286,
      "grad_norm": 0.6498947739601135,
      "learning_rate": 0.00017333333333333334,
      "loss": 0.1276,
      "step": 260
    },
    {
      "epoch": 1.4835164835164836,
      "grad_norm": 0.48399585485458374,
      "learning_rate": 0.00018,
      "loss": 0.1058,
      "step": 270
    },
    {
      "epoch": 1.5384615384615383,
      "grad_norm": 0.30425164103507996,
      "learning_rate": 0.0001866666666666667,
      "loss": 0.1046,
      "step": 280
    },
    {
      "epoch": 1.5934065934065935,
      "grad_norm": 0.44099316000938416,
      "learning_rate": 0.00019333333333333333,
      "loss": 0.1133,
      "step": 290
    },
    {
      "epoch": 1.6483516483516483,
      "grad_norm": 0.5143241286277771,
      "learning_rate": 0.0002,
      "loss": 0.1237,
      "step": 300
    },
    {
      "epoch": 1.7032967032967035,
      "grad_norm": 0.2673356831073761,
      "learning_rate": 0.000191869918699187,
      "loss": 0.1101,
      "step": 310
    },
    {
      "epoch": 1.7582417582417582,
      "grad_norm": 0.3179146349430084,
      "learning_rate": 0.000183739837398374,
      "loss": 0.113,
      "step": 320
    },
    {
      "epoch": 1.8131868131868132,
      "grad_norm": 0.37721434235572815,
      "learning_rate": 0.000175609756097561,
      "loss": 0.1113,
      "step": 330
    },
    {
      "epoch": 1.8681318681318682,
      "grad_norm": 0.4035661816596985,
      "learning_rate": 0.00016747967479674797,
      "loss": 0.1058,
      "step": 340
    },
    {
      "epoch": 1.9230769230769231,
      "grad_norm": 0.42484527826309204,
      "learning_rate": 0.00015934959349593497,
      "loss": 0.1142,
      "step": 350
    },
    {
      "epoch": 1.978021978021978,
      "grad_norm": 0.37304389476776123,
      "learning_rate": 0.00015121951219512197,
      "loss": 0.0937,
      "step": 360
    },
    {
      "epoch": 2.032967032967033,
      "grad_norm": 0.1278969645500183,
      "learning_rate": 0.00014308943089430895,
      "loss": 0.1039,
      "step": 370
    },
    {
      "epoch": 2.087912087912088,
      "grad_norm": 0.19862954318523407,
      "learning_rate": 0.00013495934959349595,
      "loss": 0.1006,
      "step": 380
    },
    {
      "epoch": 2.142857142857143,
      "grad_norm": 0.2047436237335205,
      "learning_rate": 0.00012682926829268293,
      "loss": 0.0709,
      "step": 390
    },
    {
      "epoch": 2.197802197802198,
      "grad_norm": 0.2357422411441803,
      "learning_rate": 0.00011869918699186993,
      "loss": 0.0909,
      "step": 400
    },
    {
      "epoch": 2.2527472527472527,
      "grad_norm": 0.19021956622600555,
      "learning_rate": 0.00011056910569105692,
      "loss": 0.0939,
      "step": 410
    },
    {
      "epoch": 2.3076923076923075,
      "grad_norm": 0.2202429175376892,
      "learning_rate": 0.0001024390243902439,
      "loss": 0.0972,
      "step": 420
    },
    {
      "epoch": 2.3626373626373627,
      "grad_norm": 0.24319039285182953,
      "learning_rate": 9.43089430894309e-05,
      "loss": 0.1028,
      "step": 430
    },
    {
      "epoch": 2.4175824175824174,
      "grad_norm": 0.26337578892707825,
      "learning_rate": 8.61788617886179e-05,
      "loss": 0.106,
      "step": 440
    },
    {
      "epoch": 2.4725274725274726,
      "grad_norm": 0.18105241656303406,
      "learning_rate": 7.804878048780489e-05,
      "loss": 0.08,
      "step": 450
    },
    {
      "epoch": 2.5274725274725274,
      "grad_norm": 0.3710761070251465,
      "learning_rate": 6.991869918699188e-05,
      "loss": 0.0843,
      "step": 460
    },
    {
      "epoch": 2.5824175824175826,
      "grad_norm": 0.16677603125572205,
      "learning_rate": 6.178861788617887e-05,
      "loss": 0.0929,
      "step": 470
    },
    {
      "epoch": 2.6373626373626373,
      "grad_norm": 0.06506508588790894,
      "learning_rate": 5.365853658536586e-05,
      "loss": 0.0956,
      "step": 480
    },
    {
      "epoch": 2.6923076923076925,
      "grad_norm": 0.13316453993320465,
      "learning_rate": 4.5528455284552844e-05,
      "loss": 0.0935,
      "step": 490
    },
    {
      "epoch": 2.7472527472527473,
      "grad_norm": 0.04071825370192528,
      "learning_rate": 3.739837398373984e-05,
      "loss": 0.0949,
      "step": 500
    }
  ],
  "logging_steps": 10,
  "max_steps": 546,
  "num_input_tokens_seen": 0,
  "num_train_epochs": 3,
  "save_steps": 50,
  "total_flos": 0.0,
  "train_batch_size": 128,
  "trial_name": None,
  "trial_params": None
}

# %%
# Visualize the training progress of the simcse using the loss

loss_llama_swe_simcse = [log['loss'] for log in llama_swe_mntp_simcse_da['log_history'] if 'loss' in log]
#loss_llama_swe_simcse_long_train = [log['loss'] for log in llama_swe_mntp_simcse_da_long_train['log_history'] if 'loss' in log]
loss_llama_swe_simcse_supervised_dkwiki = [log['loss'] for log in llama_swe_mntp_simcse_supervised_wiki_150['log_history'] if 'loss' in log]
loss_llama_swe_simcse_supervised_dkmix = [log['loss'] for log in llama_swe_mntp_simcse_supervised_dkmix_500['log_history'] if 'loss' in log]
loss_llama_en_simcse = [log['loss'] for log in llama_en_simcse_dk['log_history'] if 'loss' in log]

step = [log['step'] for log in llama_swe_mntp_simcse_da['log_history'] if 'loss' in log]
#step_long_train = [log['step'] for log in llama_swe_mntp_simcse_da_long_train['log_history'] if 'loss' in log]
# Multiply the steps of supervised by 4 (gradient accumulation)
step_supervised_150 = [log['step']*4 for log in llama_swe_mntp_simcse_supervised_wiki_150['log_history'] if 'loss' in log]
step_supervised_500 = [log['step']*4 for log in llama_swe_mntp_simcse_supervised_dkmix_500['log_history'] if 'loss' in log]


fig, axs = plt.subplots(1, 2, figsize=(12, 5))
axs.plot(step, loss_llama_swe_simcse, label='Simcse-dk-wiki (0.75 epoch)')
axs.plot(step, loss_llama_en_simcse, label='Simcse-en-dk (0.75 epoch)')
#axs.plot(step_long_train, loss_llama_swe_simcse_long_train, label='llama_swe_mntp_simcse_da_long_train')
axs.plot(step_supervised_150, loss_llama_swe_simcse_supervised_dkwiki, label='Supervised-dk-wiki (2.5 epochs)')
axs.plot(step_supervised_500, loss_llama_swe_simcse_supervised_dkmix, label='Supervised-dk-mix (1 epoch)')

axs.set_title('Contrastive Loss')
axs.set_xlabel('Step')
axs.set_ylabel('Loss')


axs.plot(step, loss_llama_swe_simcse, label='Simcse-dk-wiki (0.75 epoch)')
axs.plot(step, loss_llama_en_simcse, label='Llama-En-SimCSE-dk (0.75 epoch)')
#axs.plot(step_long_train, loss_llama_swe_simcse_long_train, label='llama_swe_mntp_simcse_da_long_train')
axs.plot(step_supervised_150, loss_llama_swe_simcse_supervised_dkwiki, label='Supervised-dk-wiki (2.5 epochs)')
axs.plot(step_supervised_500, loss_llama_swe_simcse_supervised_dkmix, label='Supervised-dk-mix (1 epoch)')
axs.set_title('Contrastive Loss (zoomed in)')
axs.set_xlabel('Step')
axs.set_ylabel('Loss')
axs.set_ylim(0, 0.2)

#Add legends place them in top right
axs.legend(loc='upper right')
axs.legend(loc='upper right')
plt.show()

# %% [markdown]
# ## SEB Benchmark

# %%
import seb

all_tasks = seb.get_all_tasks()
#Create a map of name and task type by irterating over all tasks
task_type_map = {}
for task in all_tasks:
    task_type_map[task.name] = task.task_type

task_type_map
# Out:
# {'Angry Tweets': 'Classification',
#  'LCC': 'Classification',
#  'Bornholm Parallel': 'BitextMining',
#  'DKHate': 'Classification',
#  'Da Political Comments': 'Classification',
#  'DanFEVER': 'Retrieval',
#  'TV2Nord Retrieval': 'Retrieval',
#  'Twitterhjerne': 'Retrieval',
#  'Massive Intent': 'Classification',
#  'Massive Scenario': 'Classification',
#  'ScaLA': 'Classification',
#  'Language Identification': 'Classification',
#  'NoReC': 'Classification',
#  'Norwegian parliament': 'Classification',
#  'Norwegian courts': 'BitextMining',
#  'VG Clustering': 'Clustering',
#  'SNL Clustering': 'Clustering',
#  'SNL Retrieval': 'Retrieval',
#  'NorQuad': 'Retrieval',
#  'SweReC': 'Classification',
#  'DaLAJ': 'Classification',
#  'SweFAQ': 'Retrieval',
#  'SwednRetrieval': 'Retrieval',
#  'SwednClustering': 'Clustering'}

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# Map filenames to labels
files_and_labels = {
    'llama_swe_simcse_wikidk_1000': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-simcse-dkwiki-1000-steps.pkl',
    'llama_swe_simcse_wikidk_1000_wikiscandi_1000': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-simcse-dk-wiki-scandi-1000-steps.pkl',
    'llama_swe_simcse_wikidk_1000_wikiscandi_500': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-simcse-dk-wiki-scandi-500-steps.pkl',
    'llama_swe_simcse_wikiscandi_2000': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-simcse-scandi-wiki-2000-steps.pkl',
    'llama_en_simcse_wikidk_1000': '../seb_eval/SEB_eval_llama-8b-en-llm2vec-simcse-dkwiki-1000-steps.pkl',
    'l2v_llama_en_simcse_1000': '../seb_eval/SEB_L2V_eval_LLM2Vec-Meta-Llama-3-8B-Instruct-mntp-unsup-simcse.pkl',
    'llama_swe_supervised_wikidk_100': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-supervised-wikigemma-100-steps.pkl',
    'llama_swe_supervised_wikidk_150': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-supervised-wikigemma-150-steps.pkl',
    'llama_swe_instruct_baseline': '../seb_eval/SEB_eval_llama-8b-swe-instruct.pkl',
    'llama_en_instruct_baseline': '../seb_eval/SEB_eval_llama-8b-instruct.pkl',
    'llama_swe_simcse_wikidk_3000': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-simcse-dkwiki-3000-steps.pkl',
    'l2v_llama_en_simcse_1000_replicated': '../seb_eval/SEB_eval_llama-8b-en-llm2vec-simcse-baseline-1000-steps.pkl',
    'llama_swe_simcse_scandi_1000_simcse_1000': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-mntp-scandiwiki-simcse-scandiwiki-1000-steps.pkl',
}

# Load and calculate scores
main_scores = {}
for label, filepath in files_and_labels.items():
    with open(filepath, 'rb') as f:
        results = pickle.load(f)
    if label == 'llama_en_simcse_wikidk_1000': #Ups did the benchmark on all SEB only first 12 is DK
        scores = [res.get_main_score() for res in results[0][:12]]
    else:
        scores = [res.get_main_score() for res in results[0]]
    mean_score = np.mean(scores)
    scores.append(mean_score)
    main_scores[label] = scores

# Task names
task_names = [res.task_name for res in results[0]]
task_names.append('Mean Score')

# Separate "Mean Score" and handle sorting for other task names
tasks_except_mean = task_names[:-1]  # Exclude 'Mean Score'
sorted_indices_except_mean = sorted(range(len(tasks_except_mean)), key=lambda k: tasks_except_mean[k])
sorted_task_names = [tasks_except_mean[i] for i in sorted_indices_except_mean]

# After sorting, re-append 'Mean Score' at the end
sorted_task_names.append('Mean Score')

# Reorder the scores in main_scores using the sorted_indices_except_mean
for key in main_scores:
    # Exclude the mean score from sorting, and sort the rest
    sorted_scores_except_mean = [main_scores[key][i] for i in sorted_indices_except_mean]
    
    # Append the 'Mean Score' at the end
    sorted_scores_except_mean.append(main_scores[key][-1])
    main_scores[key] = sorted_scores_except_mean

# Update task_names to sorted_task_names
task_names = sorted_task_names

# Multiply all scores by 100
for key in main_scores:
    main_scores[key] = [score * 100 for score in main_scores[key]]

#Manually add the below to the list
dfm_simcse = {'dfm-encoder-large-v1 (SimCSE)': [54.4, 15.9, 63.2, 38.5, 36.9, 58.1, 76.0, 65.8, 71.6, 66.1, 80.8, 17.0, 52.2]}
for key in dfm_simcse:
    main_scores[key] = dfm_simcse[key]


# Plotting
fig, ax = plt.subplots(figsize=(14, 7))
bar_width = 0.1
index = np.arange(len(task_names))

# Define the order and labeling of the plot bars
order_and_labels = [
    ('llama_en_instruct_baseline', 'Llama-8B-en-instruct'),
    ('llama_swe_instruct_baseline', 'Llama-8B-swe-instruct'),
    #('l2v_llama_en_simcse_1000', 'Llama-8B-en-simcse-en-1000-steps (L2V Paper)'),
    #('l2v_llama_en_simcse_1000_replicated', 'Llama-8B-en-simcse-en-1000-steps (L2V Replicated)'),
    ('llama_en_simcse_wikidk_1000', 'Llama-8B-en-simcse-dk-1000-steps'),
    ('llama_swe_simcse_wikidk_1000', 'Llama-8B-swe-simcse-dk-1000-steps'),
    #('llama_swe_simcse_wikidk_3000', 'Llama-8B-swe-simcse-dk-3000-steps'),
    #('llama_swe_simcse_wikidk_1000_wikiscandi_500', 'Llama-8B-swe-simcse-dk-wiki-scandi-500-steps'),
    ('llama_swe_simcse_wikidk_1000_wikiscandi_1000', 'Llama-8B-swe-mntp-dk-simcse-scandi-1000-steps'),
    ('llama_swe_simcse_scandi_1000_simcse_1000', 'Llama-8B-swe-simcse-scandi-1000-steps'),
    ('llama_swe_simcse_wikiscandi_2000', 'Llama-8B-swe-simcse-scandi-2000-steps'),
    #('llama_swe_supervised_wikidk_100', 'Llama-8B-swe-simcse-1000-supervised-400-steps'),
    #('llama_swe_supervised_wikidk_150', 'Llama-8B-swe-simse-1000-supervised-600-steps')
    ('dfm-encoder-large-v1 (SimCSE)', 'dfm-encoder-large-v1 (SimCSE)')
]




for i, (key, label) in enumerate(order_and_labels):
    ax.bar(index + i * bar_width, main_scores[key], bar_width, label=label)

ax.set_xticks(index + 2.5 * bar_width)  # Center labels
ax.set_xticklabels(task_names, rotation=90)
ax.set_ylabel('Primary Score')
ax.set_title('Scandinavian Embedding Benchmark, Various Llama Models')
ax.legend()
plt.show()

# %%
# Out:
# {'Angry Tweets': 'Classification',
#  'LCC': 'Classification',
#  'Bornholm Parallel': 'BitextMining',
#  'DKHate': 'Classification',
#  'Da Political Comments': 'Classification',
#  'DanFEVER': 'Retrieval',
#  'TV2Nord Retrieval': 'Retrieval',
#  'Twitterhjerne': 'Retrieval',
#  'Massive Intent': 'Classification',
#  'Massive Scenario': 'Classification',
#  'ScaLA': 'Classification',
#  'Language Identification': 'Classification',
#  'NoReC': 'Classification',
#  'Norwegian parliament': 'Classification',
#  'Norwegian courts': 'BitextMining',
#  'VG Clustering': 'Clustering',
#  'SNL Clustering': 'Clustering',
#  'SNL Retrieval': 'Retrieval',
#  'NorQuad': 'Retrieval',
#  'SweReC': 'Classification',
#  'DaLAJ': 'Classification',
#  'SweFAQ': 'Retrieval',
#  'SwednRetrieval': 'Retrieval',
#  'SwednClustering': 'Clustering'}

# %%
# Extract all the scores and put in table using the order_and_labels as input for names and which to include in the dataframe
# Extract the task names as columns, set the model names as index
import pandas as pd
df = pd.DataFrame()
for i, (key, label) in enumerate(order_and_labels):
    df[label] = main_scores[key]
df['Task'] = task_names
df.set_index('Task', inplace=True)
#Flip the table
df = df.T
#Add the below
# dfm-encoder-large-v1 manually to the df :(SimCSE)	54.4	15.9	63.2	38.5	36.9	58.1	76.0	65.8	71.6	66.1	80.8	17.0
#df.loc['dfm-encoder-large-v1 (SimCSE)'] = [54.4, 15.9, 63.2, 38.5, 36.9, 58.1, 76.0, 65.8, 71.6, 66.1, 80.8, 17.0, 52.2]
df.head()

#Export the table to excel
df.to_excel('SEB_benchmark_results.xlsx')

# %% [markdown]
# l2v_llama_swe_dk_results

# %%
main_scores

# %%
l2v_llama_swe_dk_results[0][-1].task_description

# %% [markdown]
# ## Exluding scandinavian language identification

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# Map filenames to labels
files_and_labels = {
    'llama_swe_simcse_wikidk_1000': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-simcse-dkwiki-1000-steps.pkl',
    'l2v_llama_en_simcse_1000': '../seb_eval/SEB_L2V_eval_LLM2Vec-Meta-Llama-3-8B-Instruct-mntp-unsup-simcse.pkl',
    'llama_swe_supervised_wikidk_100': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-supervised-wikigemma-100-steps.pkl',
    'llama_swe_supervised_wikidk_150': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-supervised-wikigemma-150-steps.pkl',
    'llama_swe_supervised_mixdk_500': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-supervised-500-steps.pkl',
    'llama_swe_instruct_baseline': '../seb_eval/SEB_eval_llama-8b-swe-instruct.pkl',
    'llama_en_instruct_baseline': '../seb_eval/SEB_eval_llama-8b-instruct.pkl',
    'llama_swe_simcse_wikidk_3000': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-simcse-dkwiki-3000-steps.pkl'
}


# Load and calculate scores
main_scores = {}
for label, filepath in files_and_labels.items():
    with open(filepath, 'rb') as f:
        results = pickle.load(f)
    scores = [res.get_main_score() for res in results[0]]
    mean_score = np.mean(scores[:-1])
    scores.append(mean_score)
    main_scores[label] = scores

# Task names
task_names = [res.task_name for res in results[0]]
task_names.append('Mean Score')

# Plotting
fig, ax = plt.subplots(figsize=(14, 7))
bar_width = 0.15
index = np.arange(len(task_names))

# Define the order and labeling of the plot bars
order_and_labels = [
    #('llama_en_instruct_baseline', 'Llama-8B-en-instruct'),
    #('llama_swe_instruct_baseline', 'Llama-8B-swe-instruct'),
    #('l2v_llama_en_simcse_1000', 'Llama-8B-en-simcse-en-1000-steps (L2V Paper)'),
    ('llama_swe_simcse_wikidk_1000', 'Llama-8B-swe-simcse-dk-1000-steps'),
    #('llama_swe_simcse_wikidk_3000', 'Llama-8B-swe-simcse-dk-3000-steps'),
    ('llama_swe_supervised_wikidk_100', 'Llama-8B-swe-simcse-1000-supervised-wiki-5200'),
    ('llama_swe_supervised_wikidk_150', 'Llama-8B-swe-simse-1000-supervised-wiki-3-epcohs'),
    ('llama_swe_supervised_mixdk_500', 'Llama-8B-swe-simcse-1000-supervised-mix-2000-steps')
]

#Make llama_swe_simcse_wikidk_1000 red,
#llama_swe_supervised_wikidk_100 brown
#llama_swe_supervised_wikidk_150 orange
#llama_swe_supervised_mixdk_500 pink
#for i, (key, label) in enumerate(order_and_labels):
#    ax.bar(index + i * bar_width, main_scores[key], bar_width, label=label)

colors = ['crimson', 'blueviolet', 'purple', 'teal']
for i, (key, label) in enumerate(order_and_labels):
    ax.bar(index + i * bar_width, main_scores[key], bar_width, label=label, color=colors[i])
    

ax.set_xticks(index + 2.5 * bar_width)  # Center labels
ax.set_xticklabels(task_names, rotation=90)
ax.set_ylabel('Primary Score')
ax.set_title('Scandinavian Embedding Benchmark, Various Llama Models')
ax.legend()
plt.show()

# %%
#Print out the scores for each task, for the llama_swe_supervised_mixdk_500 model
for i, (task, score) in enumerate(zip(task_names, main_scores['llama_swe_simcse_wikidk_1000'])):
    print(f'{task}: {score}')

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# Map filenames to labels
files_and_labels = {
    'llama_swe_simcse_wikidk_1000': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-simcse-dkwiki-1000-steps.pkl',
    'l2v_llama_en_simcse_1000': '../seb_eval/SEB_L2V_eval_LLM2Vec-Meta-Llama-3-8B-Instruct-mntp-unsup-simcse.pkl',
    'llama_swe_supervised_wikidk_100': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-supervised-wikigemma-100-steps.pkl',
    'llama_swe_supervised_wikidk_150': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-supervised-wikigemma-150-steps.pkl',
    'llama_swe_instruct_baseline': '../seb_eval/SEB_eval_llama-8b-swe-instruct.pkl',
    'llama_en_instruct_baseline': '../seb_eval/SEB_eval_llama-8b-instruct.pkl',
    'llama_swe_simcse_wikidk_3000': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-simcse-dkwiki-3000-steps.pkl',
    'llama_swe_supervised_mixdk_500': '../seb_eval/SEB_eval_llama-8b-swe-llm2vec-supervised-500-steps.pkl'
}

# Load and calculate scores
main_scores = {}
for label, filepath in files_and_labels.items():
    with open(filepath, 'rb') as f:
        results = pickle.load(f)
    scores = [res.get_main_score() for res in results[0]]
    mean_score = np.mean(scores)
    scores.append(mean_score)
    main_scores[label] = scores

# Task names
task_names = [res.task_name for res in results[0]]
task_names.append('Mean Score')
#Add linebreak to all task names that are more than 1 word
task_names = [task_name.replace(' ', '\n') for task_name in task_names]

# Plotting
fig, ax = plt.subplots(figsize=(16, 7))
bar_width = 0.15
index = np.arange(len(task_names))

# Define the order and labeling of the plot bars
order_and_labels = [
    ('llama_en_instruct_baseline', 'Llama3-8B-en instruct [en]'),
    ('llama_swe_instruct_baseline', 'Llama3-8B-swe instruct [swe]'),
    ('l2v_llama_en_simcse_1000', 'LLM2Vec-Llama3-unsupervised [en]'),
    ('llama_swe_simcse_wikidk_1000', 'L2V-llama3-unsupervised-da [swe+dk]'),
    ('llama_swe_supervised_mixdk_500', 'L2V-llama3-supervised-da [swe+dk]'),
]

#L2V
#L2V-llama-SimCSE-da 



for i, (key, label) in enumerate(order_and_labels):
    ax.bar(index -0.3 + i * bar_width, main_scores[key], bar_width, label=label)

#Add horisontal greyed out gridlines to the entire plot with 0.1 spacing on the y-axis
ax.yaxis.grid(color='gray', linestyle='-', linewidth=0.5)



ax.set_xticks(index)  # Center labels
ax.set_xticklabels(task_names, rotation=45)
ax.set_ylabel('Primary Score')

ax.set_title('Scandinavian Embedding Benchmark Scores [DA]')
ax.legend(fontsize='large')
plt.show()

# %% [markdown]
# ## CLustering tasks

# %%
import seb

all_tasks = seb.get_all_tasks()
#Create a map of name and task type by irterating over all tasks
task_type_map = {}
for task in all_tasks:
    task_type_map[task.name] = task.task_type

task_type_map

# %%
category_count = {
    "Classification": 7,
    "BitextMining": 1,
    "Retrieval": 3
}

category_scores = {}
for label, filepath in files_and_labels.items():
    with open(filepath, 'rb') as f:
        results = pickle.load(f)
    # Create the outer dictionary with the label as the key
    category_scores[label] = {}
    for res in results[0][:-1]:
        task_type = task_type_map[res.task_name]
        if task_type not in category_scores[label]:
            category_scores[label][task_type] = []
        category_scores[label][task_type].append(res.get_main_score())  

    #Calculate the mean score for each category and overwrite the list of scores with the mean score
    for task_type, scores in category_scores[label].items():
        mean_score = np.mean(scores)
        category_scores[label][task_type] = mean_score
        
category_scores

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming the dictionary `category_scores` is already defined with the data you provided

fig, ax = plt.subplots(figsize=(14, 7))

# Dynamically retrieve task types from the first dictionary (exclude 'Mean Score')
example_label = next(iter(category_scores))
task_types = [task for task in category_scores[example_label] if task != 'Mean Score']

# Create a color map
#colors = plt.cm.viridis(np.linspace(0, 1, len(order_and_labels)))

# Offset for each group
x = np.arange(len(task_types))
width = 0.1

# Iterate over each label, following the specified order
for i, (key, label) in enumerate(order_and_labels):
    if key in category_scores:
        scores = [category_scores[key][task_type] for task_type in task_types]
        
        # Plot each bar with a distinct color and position
        ax.bar(x + i*width, scores, width, label=label)

# Set the labels
ax.set_xlabel('Task Type')
ax.set_ylabel('Score')
ax.set_title('Scores by Model and Task Type')
ax.set_xticks(x + width * (len(order_and_labels) - 1) / 2)
ax.set_xticklabels(task_types)
ax.legend(title="Models")

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

order_and_labels = [
    ('llama_en_instruct_baseline', 'Llama-8B-en-instruct'),
    ('llama_swe_instruct_baseline', 'Llama-8B-swe-instruct'),
    ('l2v_llama_en_simcse_1000', 'Llama-8B-en-simcse-en-1000-steps (L2V Paper)'),
    ('llama_swe_simcse_wikidk_1000', 'Llama-8B-swe-simcse-dk-1000-steps'),
    ('llama_swe_simcse_wikidk_3000', 'Llama-8B-swe-simcse-dk-3000-steps'),
    ('llama_swe_supervised_wikidk_100', 'Llama-8B-swe-simcse-1000-supervised-400-steps'),
    ('llama_swe_supervised_wikidk_150', 'Llama-8B-swe-simse-1000-supervised-600-steps')
]

# Assuming the dictionary `category_scores` is already defined with the data you provided
import matplotlib.pyplot as plt
import numpy as np

# Assuming the dictionary `category_scores` is already defined with the data you provided

fig, ax = plt.subplots(figsize=(14, 7))

# Dynamically retrieve task types from the first dictionary (exclude 'Mean Score')
example_label = next(iter(category_scores))
task_types = [task for task in category_scores[example_label] if task != 'Mean Score']

# Create a color map
colors = plt.cm.viridis(np.linspace(0, 1, len(order_and_labels)))

# Offset for each group
x = np.arange(len(task_types))
width = 0.1

# Iterate over each label, following the specified order
for i, (key, label) in enumerate(order_and_labels):
    if key in category_scores:
        scores = [category_scores[key][task_type] for task_type in task_types]
        
        # Plot each bar with a distinct color and position
        ax.bar(x + i*width, scores, width, label=label, color=colors[i])

# Set the labels
ax.set_xlabel('Task Type')
ax.set_ylabel('Score')
ax.set_title('Scores by Model and Task Type')
ax.set_xticks(x + width * (len(order_and_labels) - 1) / 2)
ax.set_xticklabels(task_types)
ax.legend(title="Models")

# Display the plot
plt.show()

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

with open(f"../seb_eval/SEB_eval_llama-8b-swe-llm2vec-simcse-dkwiki-1000-steps.pkl", 'rb') as f:
    l2v_llama_swe_dk_results = pickle.load(f)

with open(f"../seb_eval/SEB_L2V_eval_LLM2Vec-Meta-Llama-3-8B-Instruct-mntp-unsup-simcse.pkl", 'rb') as f:
    l2v_llama_en_results = pickle.load(f)

with open(f"../seb_eval/SEB_eval_llama-8b-swe-instruct.pkl", 'rb') as f:
    llama_swe_baseline_results = pickle.load(f)

with open(f"../seb_eval/SEB_eval_llama-8b-instruct.pkl", 'rb') as f:
    llama_en_baseline_results = pickle.load(f)

with open(f"../seb_eval/SEB_eval_llama-8b-swe-llm2vec-simcse-dkwiki-3000-steps.pkl", 'rb') as f:
    llama_swe_long_train_results = pickle.load(f)

#Only include all, except the last task
task_names = [res.task_name for res in l2v_llama_swe_dk_results[0][:-1]]

task_names.append('Mean Score')
main_scores_llama_8B_swe_simcse_dk = [res.get_main_score() for res in l2v_llama_swe_dk_results[0][:-1]]
#Calculate and append the mean of the main scores for the swe simcse_dk model
mean_scores_llama_8B_swe_simcse_dk = np.mean(main_scores_llama_8B_swe_simcse_dk)
main_scores_llama_8B_swe_simcse_dk.append(mean_scores_llama_8B_swe_simcse_dk)

main_scores_llama_8B_en_simcse = [res.get_main_score() for res in l2v_llama_en_results[0][:-1]]
mean_scores_llama_8B_en_simcse = np.mean(main_scores_llama_8B_en_simcse)
main_scores_llama_8B_en_simcse.append(mean_scores_llama_8B_en_simcse)

main_scores_llama_8b_swe_baseline = [res.get_main_score() for res in llama_swe_baseline_results[0][:-1]]
mean_scores_llama_8b_swe_baseline = np.mean(main_scores_llama_8b_swe_baseline)
main_scores_llama_8b_swe_baseline.append(mean_scores_llama_8b_swe_baseline)

main_scores_llama_8b_en_baseline = [res.get_main_score() for res in llama_en_baseline_results[0][:-1]]
mean_scores_llama_8b_en_baseline = np.mean(main_scores_llama_8b_en_baseline)
main_scores_llama_8b_en_baseline.append(mean_scores_llama_8b_en_baseline)

main_scores_llama_8b_swe_long_train = [res.get_main_score() for res in llama_swe_long_train_results[0][:-1]]
mean_scores_llama_8b_swe_long_train = np.mean(main_scores_llama_8b_swe_long_train)
main_scores_llama_8b_swe_long_train.append(mean_scores_llama_8b_swe_long_train)



fig, ax = plt.subplots(figsize=(10, 5))
bar_width = 0.15
index = np.arange(len(task_names))
ax.bar(index, main_scores_llama_8B_en_simcse, bar_width, label='Llama-8B-en-simcse-en-1000-steps')
ax.bar(index + bar_width, main_scores_llama_8B_swe_simcse_dk, bar_width, label='Llama-8B-swe-simcse-dk-1000-steps')
ax.bar(index + 2*bar_width, main_scores_llama_8b_swe_long_train, bar_width, label='Llama-8B-swe-simcse-dk-3000-steps')
ax.bar(index + 3*bar_width, main_scores_llama_8b_en_baseline, bar_width, label='Llama-8B-en-instruct')
ax.bar(index + 4*bar_width, main_scores_llama_8b_swe_baseline, bar_width, label='Llama-8B-swe-instruct')

ax.set_xticks(index + bar_width )
ax.set_xticklabels(task_names, rotation=90)
ax.set_ylabel('Primary Score')
ax.set_title('Scandinavian Embedding Benchmark, Language Identification excluded')
ax.legend()
plt.show()
